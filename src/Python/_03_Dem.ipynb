# %%
import ee
import geemap
import xarray as xr
import xee
import numpy as np
import pandas as pd
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# ee.Authenticate()
# ee.Initialize(
#     project = 'drought-monitoring-iran',
#     opt_url = 'https://earthengine-highvolume.googleapis.com'
# )

SERVICE_ACCOUNT = 'gee-automation@drought-monitoring-iran.iam.gserviceaccount.com'
KEY_PATH = r'C:\Users\Pooya\Dropbox\drought-monitoring-iran-dab2ca8047be.json'

credentials = ee.ServiceAccountCredentials(SERVICE_ACCOUNT, KEY_PATH)
ee.Initialize(credentials, 
              project='drought-monitoring-iran',
              opt_url='https://earthengine-highvolume.googleapis.com')

print("Authenticated as service account:", SERVICE_ACCOUNT)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Authenticated as service account: gee-automation@drought-monitoring-iran.iam.gserviceaccount.com

# %%
# map = geemap.Map(basemap = 'SATELLITE')
# map

# %%
# roi = map.draw_last_feature.geometry()
# roi

# %%
dem = ee.Image("NASA/NASADEM_HGT/001").select('elevation')

dem
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div><style>:root {
#   --font-color-primary: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#   --font-color-secondary: var(--jp-content-font-color2, rgba(0, 0, 0, 0.7));
#   --font-color-accent: rgba(123, 31, 162, 1);
# ...

# %%
roi = geemap.shp_to_ee('C:\\Users\\Pooya\\w\\GitHub\\ShiraziAlianPooya\\panel-data-eto\\data\\ne_110m_admin_0_countries\\ne_110m_admin_0_countries.shp')

dem_clip = dem.clip(roi)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
xdem = xr.open_dataset(
    dem_clip,
    engine = 'ee',
    crs = 'EPSG:4326',
    geometry = roi.geometry(),
    scale = 0.01
)

xdem
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <xarray.Dataset> Size: 3GB
# Dimensions:    (time: 1, lon: 36000, lat: 17365)
# Coordinates:
#   * time       (time) datetime64[ns] 8B 2000-02-11
#   * lon        (lon) float64 288kB -180.0 -180.0 -180.0 ... 180.0 180.0 180.0
# ...

# %%
xdem.elevation.plot(
    x = 'lon',
    y = 'lat',
    robust = True
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# ...

# %%
from sklearn.cluster import KMeans

model = KMeans(n_clusters = 6)

model.fit(df)

df['classes'] = model.predict(df)

# %%
xarr = df.to_xarray().sortby(['lon','lat'])

xarr

# %%
xarr.classes.plot(
    x = 'lon',
    y = 'lat',
    robust = True,
    cmap = 'tab10'
)
