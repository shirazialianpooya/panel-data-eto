# %% [markdown]
# # Load Libraries

# %%
import os
import warnings
import logging
import sys
import pickle
import numpy as np
import pandas as pd
import geopandas as gpd
import dotenv
import pyet

# Load environment variables from .env file
dotenv.load_dotenv()

# Set up logging
logging.basicConfig(level=logging.INFO)

# Suppress warnings
warnings.filterwarnings("ignore")

# Set display options for pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # Load Data

# %%
# Load Data From Pickle
# with open('../../data/Khorasan_Data_1950_2025.pkl', 'rb') as f:
with open('../../data/Iran_Data_1950_2025.pkl', 'rb') as f:
    data = pickle.load(f)
    logging.info("Data loaded from pickle file.")
# Out:
# INFO:root:Data loaded from pickle file.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4928062 entries, 0 to 4928061
# Data columns (total 17 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   station_id         category
#  1   station_name       category
#  2   region_id          category
#  3   region_name        category
#  4   lat                float64
#  5   lon                float64
#  6   station_elevation  float64
#  7   date               datetime64[ns]
#  8   tmax               float64
#  9   tmin               float64
#  10  tm                 float64
#  11  umax               float64
#  12  umin               float64
#  13  um                 float64
#  14  ffm                float64
#  15  sshn               float64
#  16  rrr24              float64
# dtypes: category(4), datetime64[ns](1), float64(12)
# memory usage: 517.0 MB

# %% [markdown]
# # Calculate ETo

# %% [markdown]
# #### Data Quality Control

# %%
def data_quality_control(
    df, 
    required_vars = ['tm']
):
    # Remove duplicates
    df = df[~df.duplicated(keep='first')]
    # Drop rows with missing essential variables
    df = df.dropna(subset=required_vars)
    # Clip or filter out physically impossible values (example thresholds, adjust as needed)
    if 'tm' in required_vars:
        df = df[(df['tm'] > -50) & (df['tm'] < 60)]
    if 'tmax' in required_vars:
        df = df[(df['tmax'] > -50) & (df['tmax'] < 70)]
    if 'tmin' in required_vars:
        df = df[(df['tmin'] > -60) & (df['tmin'] < 50)]
    if 'ffm' in required_vars:
        df = df[(df['ffm'] >= 0) & (df['ffm'] < 50)]
    if 'um' in required_vars:
        df = df[(df['um'] >= 0) & (df['um'] <= 100)]
    if 'umax' in required_vars:
        df = df[(df['umax'] >= 0) & (df['umax'] <= 100)]
    if 'umin' in required_vars:
        df = df[(df['umin'] >= 0) & (df['umin'] <= 100)]
    if 'sshn' in required_vars:
        df = df[(df['sshn'] >= 0) & (df['sshn'] <= 24)]
    return df

# %% [markdown]
# #### Calculate ETo

# %%
def calculate_eto_pm_fao56(group):
    print(f"Calculating ETo pm_fao56 for station {group.name}")
    group = data_quality_control(
        df=group, 
        required_vars=['tm', 'tmax', 'tmin', 'um', 'umin', 'umax', 'ffm', 'sshn', 'lat', 'station_elevation']
    )
    group = group.set_index('date').sort_index()

    # If group is empty after cleaning, return NaNs
    if group.empty:
        return pd.Series(np.nan, index=group.index)

    lat = pyet.utils.deg_to_rad(lat=group['lat'].iloc[0])
    elevation = group['station_elevation'].iloc[0]
    rs = pyet.calc_rad_sol_in(n=group['sshn'], lat=lat, as1=0.25, bs1=0.5, nn=None)    
    wind = group['ffm']
    tmean = group['tm']
    tmax = group["tmax"]
    tmin = group["tmin"]
    rh = group["um"]
    rhmax = group["umin"]
    rhmin = group["umax"]
    
    eto = pyet.pm_fao56(
        tmean=tmean,
        wind=wind,
        rs=rs,
        elevation=elevation,
        lat=lat,
        tmax=tmax,
        tmin=tmin,
        rh=rh,
        rhmax=rhmax,
        rhmin=rhmin
    )

    return eto


def calculate_eto_hargreaves(group):
    print(f"Calculating ETo hargreaves for station {group.name}")
    group = data_quality_control(
        df=group, 
        required_vars=['tm', 'tmax', 'tmin', 'lat']
    )
    group = group.set_index('date').sort_index()

    # If group is empty after cleaning, return NaNs
    if group.empty:
        return pd.Series(np.nan, index=group.index)

    lat = pyet.utils.deg_to_rad(lat=group['lat'].iloc[0])
    tmean = group['tm']
    tmax = group["tmax"]
    tmin = group["tmin"]
    
    eto = pyet.hargreaves(
        tmean=tmean,
        tmax=tmax,
        tmin=tmin,
        lat=lat,
        k=0.0135,
        method=0,
        clip_zero=True
    )

    return eto

eto_df_pm_fao56 = data.groupby(
    ['region_id', 'station_id'],
    group_keys=True
).apply(calculate_eto_pm_fao56)

eto_df_hargreaves = data.groupby(
    ['region_id', 'station_id'],
    group_keys=True
).apply(calculate_eto_hargreaves)
# Out:
# Calculating ETo pm_fao56 for station ('ALKK', '18554')
# Calculating ETo pm_fao56 for station ('ALKK', '18590')
# Calculating ETo pm_fao56 for station ('ALKK', '18592')
# Calculating ETo pm_fao56 for station ('ALKK', '18593')
# Calculating ETo pm_fao56 for station ('ALKK', '18607')
# Calculating ETo pm_fao56 for station ('ALKK', '18622')
# Calculating ETo pm_fao56 for station ('ALKK', '18632')
# Calculating ETo pm_fao56 for station ('ALKK', '18703')
# Calculating ETo pm_fao56 for station ('ALKK', '18712')
# Calculating ETo pm_fao56 for station ('ALKK', '40752')
# Calculating ETo pm_fao56 for station ('ALKK', '75201')
# Calculating ETo pm_fao56 for station ('ALKK', '88125')
# Calculating ETo pm_fao56 for station ('ALKK', '90220')
# Calculating ETo pm_fao56 for station ('ALKK', '99321')
# Calculating ETo pm_fao56 for station ('ALKK', '99373')
# Calculating ETo pm_fao56 for station ('ALKK', '99396')
# Calculating ETo pm_fao56 for station ('MAAA', '18915')
# Calculating ETo pm_fao56 for station ('MAAA', '18975')
# Calculating ETo pm_fao56 for station ('MAAA', '19060')
# Calculating ETo pm_fao56 for station ('MAAA', '40769')
# Calculating ETo pm_fao56 for station ('MAAA', '40891')
# Calculating ETo pm_fao56 for station ('MAAA', '88132')
# Calculating ETo pm_fao56 for station ('MAAA', '99372')
# Calculating ETo pm_fao56 for station ('MAAA', '99398')
# Calculating ETo pm_fao56 for station ('MAAA', '99409')
# Calculating ETo pm_fao56 for station ('MAAA', '99410')
# Calculating ETo pm_fao56 for station ('MAAA', '99412')
# Calculating ETo pm_fao56 for station ('MAAA', '99424')
# Calculating ETo pm_fao56 for station ('MAAA', '99432')
# Calculating ETo pm_fao56 for station ('MAAA', '99439')
# Calculating ETo pm_fao56 for station ('MAAA', '99441')
# Calculating ETo pm_fao56 for station ('MAAA', '99443')
# Calculating ETo pm_fao56 for station ('MAAA', '99461')
# Calculating ETo pm_fao56 for station ('MASA', '18332')
# Calculating ETo pm_fao56 for station ('MASA', '18377')
# Calculating ETo pm_fao56 for station ('MASA', '18389')
# Calculating ETo pm_fao56 for station ('MASA', '18410')
# Calculating ETo pm_fao56 for station ('MASA', '18420')
# Calculating ETo pm_fao56 for station ('MASA', '18423')
# Calculating ETo pm_fao56 for station ('MASA', '18488')
# Calculating ETo pm_fao56 for station ('MASA', '24002')
# Calculating ETo pm_fao56 for station ('MASA', '40732')
# Calculating ETo pm_fao56 for station ('MASA', '40734')
# Calculating ETo pm_fao56 for station ('MASA', '40735')
# Calculating ETo pm_fao56 for station ('MASA', '40736')
# Calculating ETo pm_fao56 for station ('MASA', '40737')
# Calculating ETo pm_fao56 for station ('MASA', '40759')
# Calculating ETo pm_fao56 for station ('MASA', '40760')
# Calculating ETo pm_fao56 for station ('MASA', '40788')
# Calculating ETo pm_fao56 for station ('MASA', '99299')
# Calculating ETo pm_fao56 for station ('MASA', '99306')
# Calculating ETo pm_fao56 for station ('MASA', '99308')
# Calculating ETo pm_fao56 for station ('MASA', '99309')
# Calculating ETo pm_fao56 for station ('MASA', '99340')
# Calculating ETo pm_fao56 for station ('MASA', '99348')
# Calculating ETo pm_fao56 for station ('MASA', '99357')
# Calculating ETo pm_fao56 for station ('MASA', '99360')
# Calculating ETo pm_fao56 for station ('MASA', '99361')
# Calculating ETo pm_fao56 for station ('OIAW', '19478')
# Calculating ETo pm_fao56 for station ('OIAW', '19497')
# Calculating ETo pm_fao56 for station ('OIAW', '19499')
# Calculating ETo pm_fao56 for station ('OIAW', '19569')
# Calculating ETo pm_fao56 for station ('OIAW', '40794')
# Calculating ETo pm_fao56 for station ('OIAW', '40795')
# Calculating ETo pm_fao56 for station ('OIAW', '40810')
# Calculating ETo pm_fao56 for station ('OIAW', '40811')
# Calculating ETo pm_fao56 for station ('OIAW', '40812')
# Calculating ETo pm_fao56 for station ('OIAW', '40813')
# Calculating ETo pm_fao56 for station ('OIAW', '40830')
# Calculating ETo pm_fao56 for station ('OIAW', '40831')
# Calculating ETo pm_fao56 for station ('OIAW', '40832')
# Calculating ETo pm_fao56 for station ('OIAW', '40833')
# Calculating ETo pm_fao56 for station ('OIAW', '40834')
# Calculating ETo pm_fao56 for station ('OIAW', '99446')
# Calculating ETo pm_fao56 for station ('OIAW', '99455')
# Calculating ETo pm_fao56 for station ('OIAW', '99456')
# Calculating ETo pm_fao56 for station ('OIAW', '99493')
# Calculating ETo pm_fao56 for station ('OIAW', '99508')
# Calculating ETo pm_fao56 for station ('OIAW', '99513')
# Calculating ETo pm_fao56 for station ('OIAW', '99514')
# Calculating ETo pm_fao56 for station ('OIAW', '99527')
# Calculating ETo pm_fao56 for station ('OIAW', '99535')
# Calculating ETo pm_fao56 for station ('OIAW', '99537')
# Calculating ETo pm_fao56 for station ('OIAW', '99538')
# Calculating ETo pm_fao56 for station ('OIBB', '19749')
# Calculating ETo pm_fao56 for station ('OIBB', '19751')
# Calculating ETo pm_fao56 for station ('OIBB', '19775')
# Calculating ETo pm_fao56 for station ('OIBB', '19779')
# Calculating ETo pm_fao56 for station ('OIBB', '19799')
# Calculating ETo pm_fao56 for station ('OIBB', '19851')
# Calculating ETo pm_fao56 for station ('OIBB', '19862')
# Calculating ETo pm_fao56 for station ('OIBB', '19865')
# Calculating ETo pm_fao56 for station ('OIBB', '19880')
# Calculating ETo pm_fao56 for station ('OIBB', '19886')
# Calculating ETo pm_fao56 for station ('OIBB', '19958')
# Calculating ETo pm_fao56 for station ('OIBB', '40845')
# Calculating ETo pm_fao56 for station ('OIBB', '40846')
# Calculating ETo pm_fao56 for station ('OIBB', '40857')
# Calculating ETo pm_fao56 for station ('OIBB', '40858')
# Calculating ETo pm_fao56 for station ('OIBB', '40872')
# Calculating ETo pm_fao56 for station ('OIBB', '88172')
# Calculating ETo pm_fao56 for station ('OIBB', '88187')
# Calculating ETo pm_fao56 for station ('OIBB', '88188')
# Calculating ETo pm_fao56 for station ('OIBB', '99594')
# Calculating ETo pm_fao56 for station ('OIBB', '99600')
# Calculating ETo pm_fao56 for station ('OICC', '18883')
# Calculating ETo pm_fao56 for station ('OICC', '18892')
# Calculating ETo pm_fao56 for station ('OICC', '18910')
# Calculating ETo pm_fao56 for station ('OICC', '18968')
# Calculating ETo pm_fao56 for station ('OICC', '18981')
# Calculating ETo pm_fao56 for station ('OICC', '18991')
# Calculating ETo pm_fao56 for station ('OICC', '18993')
# Calculating ETo pm_fao56 for station ('OICC', '19000')
# Calculating ETo pm_fao56 for station ('OICC', '19010')
# Calculating ETo pm_fao56 for station ('OICC', '19018')
# Calculating ETo pm_fao56 for station ('OICC', '19044')
# Calculating ETo pm_fao56 for station ('OICC', '19053')
# Calculating ETo pm_fao56 for station ('OICC', '19068')
# Calculating ETo pm_fao56 for station ('OICC', '40764')
# Calculating ETo pm_fao56 for station ('OICC', '40765')
# Calculating ETo pm_fao56 for station ('OICC', '40766')
# Calculating ETo pm_fao56 for station ('OICC', '40771')
# Calculating ETo pm_fao56 for station ('OICC', '40779')
# Calculating ETo pm_fao56 for station ('OICC', '99427')
# Calculating ETo pm_fao56 for station ('OICC', '99428')
# Calculating ETo pm_fao56 for station ('OICC', '99429')
# Calculating ETo pm_fao56 for station ('OICC', '99430')
# Calculating ETo pm_fao56 for station ('OICC', '99431')
# Calculating ETo pm_fao56 for station ('OICC', '99435')
# Calculating ETo pm_fao56 for station ('OICC', '99454')
# Calculating ETo pm_fao56 for station ('OICC', '99621')
# Calculating ETo pm_fao56 for station ('OICI', '19111')
# Calculating ETo pm_fao56 for station ('OICI', '19123')
# Calculating ETo pm_fao56 for station ('OICI', '19163')
# Calculating ETo pm_fao56 for station ('OICI', '19184')
# Calculating ETo pm_fao56 for station ('OICI', '40780')
# Calculating ETo pm_fao56 for station ('OICI', '40781')
# Calculating ETo pm_fao56 for station ('OICI', '40796')
# Calculating ETo pm_fao56 for station ('OICI', '40842')
# Calculating ETo pm_fao56 for station ('OICI', '99433')
# Calculating ETo pm_fao56 for station ('OICI', '99463')
# Calculating ETo pm_fao56 for station ('OICI', '99466')
# Calculating ETo pm_fao56 for station ('OICI', '99488')
# Calculating ETo pm_fao56 for station ('OICK', '19124')
# Calculating ETo pm_fao56 for station ('OICK', '19164')
# Calculating ETo pm_fao56 for station ('OICK', '40773')
# Calculating ETo pm_fao56 for station ('OICK', '40774')
# Calculating ETo pm_fao56 for station ('OICK', '40776')
# Calculating ETo pm_fao56 for station ('OICK', '40782')
# Calculating ETo pm_fao56 for station ('OICK', '40783')
# Calculating ETo pm_fao56 for station ('OICK', '40786')
# Calculating ETo pm_fao56 for station ('OICK', '99438')
# Calculating ETo pm_fao56 for station ('OICK', '99444')
# Calculating ETo pm_fao56 for station ('OICK', '99445')
# Calculating ETo pm_fao56 for station ('OICK', '99468')
# Calculating ETo pm_fao56 for station ('OICK', '99471')
# Calculating ETo pm_fao56 for station ('OICK', '99474')
# Calculating ETo pm_fao56 for station ('OICK', '99475')
# Calculating ETo pm_fao56 for station ('OICK', '99485')
# Calculating ETo pm_fao56 for station ('OICK', '99501')
# Calculating ETo pm_fao56 for station ('OICK', '99502')
# Calculating ETo pm_fao56 for station ('OICS', '18464')
# Calculating ETo pm_fao56 for station ('OICS', '18480')
# Calculating ETo pm_fao56 for station ('OICS', '18481')
# Calculating ETo pm_fao56 for station ('OICS', '18546')
# Calculating ETo pm_fao56 for station ('OICS', '18611')
# Calculating ETo pm_fao56 for station ('OICS', '18640')
# Calculating ETo pm_fao56 for station ('OICS', '18728')
# Calculating ETo pm_fao56 for station ('OICS', '18744')
# Calculating ETo pm_fao56 for station ('OICS', '18753')
# Calculating ETo pm_fao56 for station ('OICS', '18773')
# Calculating ETo pm_fao56 for station ('OICS', '18828')
# Calculating ETo pm_fao56 for station ('OICS', '18833')
# Calculating ETo pm_fao56 for station ('OICS', '18840')
# Calculating ETo pm_fao56 for station ('OICS', '18847')
# Calculating ETo pm_fao56 for station ('OICS', '18867')
# Calculating ETo pm_fao56 for station ('OICS', '18885')
# Calculating ETo pm_fao56 for station ('OICS', '40727')
# Calculating ETo pm_fao56 for station ('OICS', '40747')
# Calculating ETo pm_fao56 for station ('OICS', '40748')
# Calculating ETo pm_fao56 for station ('OICS', '40749')
# Calculating ETo pm_fao56 for station ('OICS', '40750')
# Calculating ETo pm_fao56 for station ('OICS', '40772')
# Calculating ETo pm_fao56 for station ('OICS', '99280')
# Calculating ETo pm_fao56 for station ('OICS', '99382')
# Calculating ETo pm_fao56 for station ('OICS', '99425')
# Calculating ETo pm_fao56 for station ('OIFM', '18162')
# Calculating ETo pm_fao56 for station ('OIFM', '18633')
# Calculating ETo pm_fao56 for station ('OIFM', '19048')
# Calculating ETo pm_fao56 for station ('OIFM', '19100')
# Calculating ETo pm_fao56 for station ('OIFM', '19118')
# Calculating ETo pm_fao56 for station ('OIFM', '19149')
# Calculating ETo pm_fao56 for station ('OIFM', '19156')
# Calculating ETo pm_fao56 for station ('OIFM', '19173')
# Calculating ETo pm_fao56 for station ('OIFM', '19176')
# Calculating ETo pm_fao56 for station ('OIFM', '19198')
# Calculating ETo pm_fao56 for station ('OIFM', '19208')
# Calculating ETo pm_fao56 for station ('OIFM', '19234')
# Calculating ETo pm_fao56 for station ('OIFM', '19248')
# Calculating ETo pm_fao56 for station ('OIFM', '19254')
# Calculating ETo pm_fao56 for station ('OIFM', '19265')
# Calculating ETo pm_fao56 for station ('OIFM', '19267')
# Calculating ETo pm_fao56 for station ('OIFM', '19293')
# Calculating ETo pm_fao56 for station ('OIFM', '19299')
# Calculating ETo pm_fao56 for station ('OIFM', '19563')
# Calculating ETo pm_fao56 for station ('OIFM', '40785')
# Calculating ETo pm_fao56 for station ('OIFM', '40787')
# Calculating ETo pm_fao56 for station ('OIFM', '40789')
# Calculating ETo pm_fao56 for station ('OIFM', '40799')
# Calculating ETo pm_fao56 for station ('OIFM', '40800')
# Calculating ETo pm_fao56 for station ('OIFM', '40801')
# Calculating ETo pm_fao56 for station ('OIFM', '40802')
# Calculating ETo pm_fao56 for station ('OIFM', '40803')
# Calculating ETo pm_fao56 for station ('OIFM', '40815')
# Calculating ETo pm_fao56 for station ('OIFM', '99417')
# Calculating ETo pm_fao56 for station ('OIFM', '99421')
# Calculating ETo pm_fao56 for station ('OIFM', '99447')
# Calculating ETo pm_fao56 for station ('OIFM', '99449')
# Calculating ETo pm_fao56 for station ('OIFM', '99452')
# Calculating ETo pm_fao56 for station ('OIFM', '99473')
# Calculating ETo pm_fao56 for station ('OIFM', '99482')
# Calculating ETo pm_fao56 for station ('OIFM', '99484')
# Calculating ETo pm_fao56 for station ('OIFM', '99489')
# Calculating ETo pm_fao56 for station ('OIFM', '99496')
# Calculating ETo pm_fao56 for station ('OIFM', '99497')
# Calculating ETo pm_fao56 for station ('OIFM', '99505')
# Calculating ETo pm_fao56 for station ('OIFM', '99506')
# Calculating ETo pm_fao56 for station ('OIFM', '99507')
# Calculating ETo pm_fao56 for station ('OIFM', '99515')
# Calculating ETo pm_fao56 for station ('OIFS', '19229')
# Calculating ETo pm_fao56 for station ('OIFS', '19245')
# Calculating ETo pm_fao56 for station ('OIFS', '19246')
# Calculating ETo pm_fao56 for station ('OIFS', '19300')
# Calculating ETo pm_fao56 for station ('OIFS', '19304')
# Calculating ETo pm_fao56 for station ('OIFS', '19350')
# Calculating ETo pm_fao56 for station ('OIFS', '19380')
# Calculating ETo pm_fao56 for station ('OIFS', '19391')
# Calculating ETo pm_fao56 for station ('OIFS', '19393')
# Calculating ETo pm_fao56 for station ('OIFS', '19439')
# Calculating ETo pm_fao56 for station ('OIFS', '19462')
# Calculating ETo pm_fao56 for station ('OIFS', '19463')
# Calculating ETo pm_fao56 for station ('OIFS', '19526')
# Calculating ETo pm_fao56 for station ('OIFS', '40797')
# Calculating ETo pm_fao56 for station ('OIFS', '40798')
# Calculating ETo pm_fao56 for station ('OIFS', '40814')
# Calculating ETo pm_fao56 for station ('OIFS', '99459')
# Calculating ETo pm_fao56 for station ('OIFS', '99503')
# Calculating ETo pm_fao56 for station ('OIFS', '99504')
# Calculating ETo pm_fao56 for station ('OIFS', '99509')
# Calculating ETo pm_fao56 for station ('OIFS', '99512')
# Calculating ETo pm_fao56 for station ('OIFS', '99518')
# Calculating ETo pm_fao56 for station ('OIFS', '99523')
# Calculating ETo pm_fao56 for station ('OIGG', '18052')
# Calculating ETo pm_fao56 for station ('OIGG', '18083')
# Calculating ETo pm_fao56 for station ('OIGG', '18131')
# Calculating ETo pm_fao56 for station ('OIGG', '18141')
# Calculating ETo pm_fao56 for station ('OIGG', '18143')
# Calculating ETo pm_fao56 for station ('OIGG', '18147')
# Calculating ETo pm_fao56 for station ('OIGG', '18171')
# Calculating ETo pm_fao56 for station ('OIGG', '18205')
# Calculating ETo pm_fao56 for station ('OIGG', '18219')
# Calculating ETo pm_fao56 for station ('OIGG', '18221')
# Calculating ETo pm_fao56 for station ('OIGG', '18231')
# Calculating ETo pm_fao56 for station ('OIGG', '18235')
# Calculating ETo pm_fao56 for station ('OIGG', '18245')
# Calculating ETo pm_fao56 for station ('OIGG', '18253')
# Calculating ETo pm_fao56 for station ('OIGG', '18261')
# Calculating ETo pm_fao56 for station ('OIGG', '18264')
# Calculating ETo pm_fao56 for station ('OIGG', '18335')
# Calculating ETo pm_fao56 for station ('OIGG', '18367')
# Calculating ETo pm_fao56 for station ('OIGG', '18572')
# Calculating ETo pm_fao56 for station ('OIGG', '40709')
# Calculating ETo pm_fao56 for station ('OIGG', '40718')
# Calculating ETo pm_fao56 for station ('OIGG', '40719')
# Calculating ETo pm_fao56 for station ('OIGG', '40720')
# Calculating ETo pm_fao56 for station ('OIGG', '40805')
# Calculating ETo pm_fao56 for station ('OIGG', '75059')
# Calculating ETo pm_fao56 for station ('OIGG', '99249')
# Calculating ETo pm_fao56 for station ('OIGG', '99268')
# Calculating ETo pm_fao56 for station ('OIGG', '99272')
# Calculating ETo pm_fao56 for station ('OIGG', '99276')
# Calculating ETo pm_fao56 for station ('OIGG', '99281')
# Calculating ETo pm_fao56 for station ('OIGG', '99282')
# Calculating ETo pm_fao56 for station ('OIGG', '99302')
# Calculating ETo pm_fao56 for station ('OIGG', '99317')
# Calculating ETo pm_fao56 for station ('OIHH', '18783')
# Calculating ETo pm_fao56 for station ('OIHH', '18895')
# Calculating ETo pm_fao56 for station ('OIHH', '18905')
# Calculating ETo pm_fao56 for station ('OIHH', '18920')
# Calculating ETo pm_fao56 for station ('OIHH', '18952')
# Calculating ETo pm_fao56 for station ('OIHH', '40768')
# Calculating ETo pm_fao56 for station ('OIHH', '40775')
# Calculating ETo pm_fao56 for station ('OIHH', '40886')
# Calculating ETo pm_fao56 for station ('OIHH', '75448')
# Calculating ETo pm_fao56 for station ('OIHH', '99380')
# Calculating ETo pm_fao56 for station ('OIHH', '99384')
# Calculating ETo pm_fao56 for station ('OIHH', '99385')
# Calculating ETo pm_fao56 for station ('OIHH', '99387')
# Calculating ETo pm_fao56 for station ('OIHH', '99388')
# Calculating ETo pm_fao56 for station ('OIHH', '99420')
# Calculating ETo pm_fao56 for station ('OIHH', '99422')
# Calculating ETo pm_fao56 for station ('OIID', '40753')
# Calculating ETo pm_fao56 for station ('OIID', '40767')
# Calculating ETo pm_fao56 for station ('OIID', '40897')
# Calculating ETo pm_fao56 for station ('OIID', '99437')
# Calculating ETo pm_fao56 for station ('OIII', '18610')
# Calculating ETo pm_fao56 for station ('OIII', '18668')
# Calculating ETo pm_fao56 for station ('OIII', '18698')
# Calculating ETo pm_fao56 for station ('OIII', '18720')
# Calculating ETo pm_fao56 for station ('OIII', '18761')
# Calculating ETo pm_fao56 for station ('OIII', '18803')
# Calculating ETo pm_fao56 for station ('OIII', '18805')
# Calculating ETo pm_fao56 for station ('OIII', '40751')
# Calculating ETo pm_fao56 for station ('OIII', '40754')
# Calculating ETo pm_fao56 for station ('OIII', '40755')
# Calculating ETo pm_fao56 for station ('OIII', '40756')
# Calculating ETo pm_fao56 for station ('OIII', '40777')
# Calculating ETo pm_fao56 for station ('OIII', '99320')
# Calculating ETo pm_fao56 for station ('OIII', '99331')
# Calculating ETo pm_fao56 for station ('OIII', '99366')
# Calculating ETo pm_fao56 for station ('OIII', '99369')
# Calculating ETo pm_fao56 for station ('OIII', '99370')
# Calculating ETo pm_fao56 for station ('OIII', '99375')
# Calculating ETo pm_fao56 for station ('OIII', '99406')
# Calculating ETo pm_fao56 for station ('OIII', '99999')
# Calculating ETo pm_fao56 for station ('OIIK', '18440')
# Calculating ETo pm_fao56 for station ('OIIK', '18514')
# Calculating ETo pm_fao56 for station ('OIIK', '18545')
# Calculating ETo pm_fao56 for station ('OIIK', '18548')
# Calculating ETo pm_fao56 for station ('OIIK', '18695')
# Calculating ETo pm_fao56 for station ('OIIK', '40731')
# Calculating ETo pm_fao56 for station ('OIIK', '99301')
# Calculating ETo pm_fao56 for station ('OIIK', '99303')
# Calculating ETo pm_fao56 for station ('OIIK', '99310')
# Calculating ETo pm_fao56 for station ('OIIK', '99319')
# Calculating ETo pm_fao56 for station ('OIIK', '99327')
# Calculating ETo pm_fao56 for station ('OIIK', '99355')
# Calculating ETo pm_fao56 for station ('OIIK', '99365')
# Calculating ETo pm_fao56 for station ('OIIK', '99367')
# Calculating ETo pm_fao56 for station ('OIIK', '99368')
# Calculating ETo pm_fao56 for station ('OIIS', '18462')
# Calculating ETo pm_fao56 for station ('OIIS', '18577')
# Calculating ETo pm_fao56 for station ('OIIS', '18608')
# Calculating ETo pm_fao56 for station ('OIIS', '18719')
# Calculating ETo pm_fao56 for station ('OIIS', '18756')
# Calculating ETo pm_fao56 for station ('OIIS', '18797')
# Calculating ETo pm_fao56 for station ('OIIS', '18859')
# Calculating ETo pm_fao56 for station ('OIIS', '18873')
# Calculating ETo pm_fao56 for station ('OIIS', '40739')
# Calculating ETo pm_fao56 for station ('OIIS', '40742')
# Calculating ETo pm_fao56 for station ('OIIS', '40757')
# Calculating ETo pm_fao56 for station ('OIIS', '40758')
# Calculating ETo pm_fao56 for station ('OIIS', '40761')
# Calculating ETo pm_fao56 for station ('OIIS', '88120')
# Calculating ETo pm_fao56 for station ('OIIS', '88130')
# Calculating ETo pm_fao56 for station ('OIIS', '90250')
# Calculating ETo pm_fao56 for station ('OIIS', '99277')
# Calculating ETo pm_fao56 for station ('OIIS', '99336')
# Calculating ETo pm_fao56 for station ('OIIS', '99386')
# Calculating ETo pm_fao56 for station ('OIIS', '99405')
# Calculating ETo pm_fao56 for station ('OIKB', '19893')
# Calculating ETo pm_fao56 for station ('OIKB', '19899')
# Calculating ETo pm_fao56 for station ('OIKB', '19926')
# Calculating ETo pm_fao56 for station ('OIKB', '19945')
# Calculating ETo pm_fao56 for station ('OIKB', '19948')
# Calculating ETo pm_fao56 for station ('OIKB', '40863')
# Calculating ETo pm_fao56 for station ('OIKB', '40875')
# Calculating ETo pm_fao56 for station ('OIKB', '40876')
# Calculating ETo pm_fao56 for station ('OIKB', '40880')
# Calculating ETo pm_fao56 for station ('OIKB', '40881')
# Calculating ETo pm_fao56 for station ('OIKB', '40882')
# Calculating ETo pm_fao56 for station ('OIKB', '40883')
# Calculating ETo pm_fao56 for station ('OIKB', '40884')
# Calculating ETo pm_fao56 for station ('OIKB', '40889')
# Calculating ETo pm_fao56 for station ('OIKB', '40890')
# Calculating ETo pm_fao56 for station ('OIKB', '40893')
# Calculating ETo pm_fao56 for station ('OIKB', '99656')
# Calculating ETo pm_fao56 for station ('OIKB', '99665')
# Calculating ETo pm_fao56 for station ('OIKB', '99666')
# Calculating ETo pm_fao56 for station ('OIKB', '99674')
# Calculating ETo pm_fao56 for station ('OIKB', '99675')
# Calculating ETo pm_fao56 for station ('OIKB', '99680')
# Calculating ETo pm_fao56 for station ('OIKB', '99688')
# Calculating ETo pm_fao56 for station ('OIKK', '19504')
# Calculating ETo pm_fao56 for station ('OIKK', '19520')
# Calculating ETo pm_fao56 for station ('OIKK', '19554')
# Calculating ETo pm_fao56 for station ('OIKK', '19579')
# Calculating ETo pm_fao56 for station ('OIKK', '19632')
# Calculating ETo pm_fao56 for station ('OIKK', '19650')
# Calculating ETo pm_fao56 for station ('OIKK', '19668')
# Calculating ETo pm_fao56 for station ('OIKK', '19680')
# Calculating ETo pm_fao56 for station ('OIKK', '19710')
# Calculating ETo pm_fao56 for station ('OIKK', '19765')
# Calculating ETo pm_fao56 for station ('OIKK', '19769')
# Calculating ETo pm_fao56 for station ('OIKK', '19805')
# Calculating ETo pm_fao56 for station ('OIKK', '19807')
# Calculating ETo pm_fao56 for station ('OIKK', '19816')
# Calculating ETo pm_fao56 for station ('OIKK', '19854')
# Calculating ETo pm_fao56 for station ('OIKK', '19863')
# Calculating ETo pm_fao56 for station ('OIKK', '19888')
# Calculating ETo pm_fao56 for station ('OIKK', '19891')
# Calculating ETo pm_fao56 for station ('OIKK', '19917')
# Calculating ETo pm_fao56 for station ('OIKK', '19922')
# Calculating ETo pm_fao56 for station ('OIKK', '19923')
# Calculating ETo pm_fao56 for station ('OIKK', '40839')
# Calculating ETo pm_fao56 for station ('OIKK', '40841')
# Calculating ETo pm_fao56 for station ('OIKK', '40843')
# Calculating ETo pm_fao56 for station ('OIKK', '40849')
# Calculating ETo pm_fao56 for station ('OIKK', '40851')
# Calculating ETo pm_fao56 for station ('OIKK', '40852')
# Calculating ETo pm_fao56 for station ('OIKK', '40853')
# Calculating ETo pm_fao56 for station ('OIKK', '40854')
# Calculating ETo pm_fao56 for station ('OIKK', '40866')
# Calculating ETo pm_fao56 for station ('OIKK', '40877')
# Calculating ETo pm_fao56 for station ('OIKK', '88170')
# Calculating ETo pm_fao56 for station ('OIKK', '88175')
# Calculating ETo pm_fao56 for station ('OIKK', '88180')
# Calculating ETo pm_fao56 for station ('OIKK', '99534')
# Calculating ETo pm_fao56 for station ('OIKK', '99549')
# Calculating ETo pm_fao56 for station ('OIKK', '99550')
# Calculating ETo pm_fao56 for station ('OIKK', '99562')
# Calculating ETo pm_fao56 for station ('OIKK', '99576')
# Calculating ETo pm_fao56 for station ('OIKK', '99583')
# Calculating ETo pm_fao56 for station ('OIKK', '99625')
# Calculating ETo pm_fao56 for station ('OIMB', '18535')
# Calculating ETo pm_fao56 for station ('OIMB', '19003')
# Calculating ETo pm_fao56 for station ('OIMB', '19041')
# Calculating ETo pm_fao56 for station ('OIMB', '19062')
# Calculating ETo pm_fao56 for station ('OIMB', '19125')
# Calculating ETo pm_fao56 for station ('OIMB', '19178')
# Calculating ETo pm_fao56 for station ('OIMB', '19180')
# Calculating ETo pm_fao56 for station ('OIMB', '19261')
# Calculating ETo pm_fao56 for station ('OIMB', '19262')
# Calculating ETo pm_fao56 for station ('OIMB', '19263')
# Calculating ETo pm_fao56 for station ('OIMB', '19394')
# Calculating ETo pm_fao56 for station ('OIMB', '19516')
# Calculating ETo pm_fao56 for station ('OIMB', '40791')
# Calculating ETo pm_fao56 for station ('OIMB', '40792')
# Calculating ETo pm_fao56 for station ('OIMB', '40793')
# Calculating ETo pm_fao56 for station ('OIMB', '40809')
# Calculating ETo pm_fao56 for station ('OIMB', '40827')
# Calculating ETo pm_fao56 for station ('OIMB', '88150')
# Calculating ETo pm_fao56 for station ('OIMB', '99401')
# Calculating ETo pm_fao56 for station ('OIMB', '99402')
# Calculating ETo pm_fao56 for station ('OIMB', '99407')
# Calculating ETo pm_fao56 for station ('OIMB', '99442')
# Calculating ETo pm_fao56 for station ('OIMB', '99448')
# Calculating ETo pm_fao56 for station ('OIMB', '99499')
# Calculating ETo pm_fao56 for station ('OIMB', '99536')
# Calculating ETo pm_fao56 for station ('OIMB', '99546')
# Calculating ETo pm_fao56 for station ('OIMM', '151655')
# Calculating ETo pm_fao56 for station ('OIMM', '18372')
# Calculating ETo pm_fao56 for station ('OIMM', '18465')
# Calculating ETo pm_fao56 for station ('OIMM', '18492')
# Calculating ETo pm_fao56 for station ('OIMM', '18604')
# Calculating ETo pm_fao56 for station ('OIMM', '18605')
# Calculating ETo pm_fao56 for station ('OIMM', '18606')
# Calculating ETo pm_fao56 for station ('OIMM', '18839')
# Calculating ETo pm_fao56 for station ('OIMM', '18889')
# Calculating ETo pm_fao56 for station ('OIMM', '18890')
# Calculating ETo pm_fao56 for station ('OIMM', '18891')
# Calculating ETo pm_fao56 for station ('OIMM', '40740')
# Calculating ETo pm_fao56 for station ('OIMM', '40741')
# Calculating ETo pm_fao56 for station ('OIMM', '40743')
# Calculating ETo pm_fao56 for station ('OIMM', '40744')
# Calculating ETo pm_fao56 for station ('OIMM', '40745')
# Calculating ETo pm_fao56 for station ('OIMM', '40746')
# Calculating ETo pm_fao56 for station ('OIMM', '40762')
# Calculating ETo pm_fao56 for station ('OIMM', '40763')
# Calculating ETo pm_fao56 for station ('OIMM', '40778')
# Calculating ETo pm_fao56 for station ('OIMM', '40806')
# Calculating ETo pm_fao56 for station ('OIMM', '40807')
# Calculating ETo pm_fao56 for station ('OIMM', '40825')
# Calculating ETo pm_fao56 for station ('OIMM', '40837')
# Calculating ETo pm_fao56 for station ('OIMM', '51202')
# Calculating ETo pm_fao56 for station ('OIMM', '51212')
# Calculating ETo pm_fao56 for station ('OIMM', '88122')
# Calculating ETo pm_fao56 for station ('OIMM', '99289')
# Calculating ETo pm_fao56 for station ('OIMM', '99315')
# Calculating ETo pm_fao56 for station ('OIMM', '99324')
# Calculating ETo pm_fao56 for station ('OIMM', '99356')
# Calculating ETo pm_fao56 for station ('OIMM', '99371')
# Calculating ETo pm_fao56 for station ('OIMM', '99434')
# Calculating ETo pm_fao56 for station ('OIMM', '99436')
# Calculating ETo pm_fao56 for station ('OIMN', '18066')
# Calculating ETo pm_fao56 for station ('OIMN', '18102')
# Calculating ETo pm_fao56 for station ('OIMN', '18105')
# Calculating ETo pm_fao56 for station ('OIMN', '18120')
# Calculating ETo pm_fao56 for station ('OIMN', '18123')
# Calculating ETo pm_fao56 for station ('OIMN', '18153')
# Calculating ETo pm_fao56 for station ('OIMN', '18166')
# Calculating ETo pm_fao56 for station ('OIMN', '18168')
# Calculating ETo pm_fao56 for station ('OIMN', '18203')
# Calculating ETo pm_fao56 for station ('OIMN', '18210')
# Calculating ETo pm_fao56 for station ('OIMN', '18213')
# Calculating ETo pm_fao56 for station ('OIMN', '18224')
# Calculating ETo pm_fao56 for station ('OIMN', '18254')
# Calculating ETo pm_fao56 for station ('OIMN', '18260')
# Calculating ETo pm_fao56 for station ('OIMN', '18275')
# Calculating ETo pm_fao56 for station ('OIMN', '18363')
# Calculating ETo pm_fao56 for station ('OIMN', '40723')
# Calculating ETo pm_fao56 for station ('OIMN', '99245')
# Calculating ETo pm_fao56 for station ('OIMN', '99262')
# Calculating ETo pm_fao56 for station ('OIMN', '99266')
# Calculating ETo pm_fao56 for station ('OIMN', '99270')
# Calculating ETo pm_fao56 for station ('OIMN', '99287')
# Calculating ETo pm_fao56 for station ('OIMN', '99295')
# Calculating ETo pm_fao56 for station ('OING', '18098')
# Calculating ETo pm_fao56 for station ('OING', '18134')
# Calculating ETo pm_fao56 for station ('OING', '18181')
# Calculating ETo pm_fao56 for station ('OING', '18193')
# Calculating ETo pm_fao56 for station ('OING', '18255')
# Calculating ETo pm_fao56 for station ('OING', '18259')
# Calculating ETo pm_fao56 for station ('OING', '18273')
# Calculating ETo pm_fao56 for station ('OING', '18280')
# Calculating ETo pm_fao56 for station ('OING', '18286')
# Calculating ETo pm_fao56 for station ('OING', '18301')
# Calculating ETo pm_fao56 for station ('OING', '18326')
# Calculating ETo pm_fao56 for station ('OING', '18339')
# Calculating ETo pm_fao56 for station ('OING', '18366')
# Calculating ETo pm_fao56 for station ('OING', '40721')
# Calculating ETo pm_fao56 for station ('OING', '40738')
# Calculating ETo pm_fao56 for station ('OING', '88113')
# Calculating ETo pm_fao56 for station ('OING', '99237')
# Calculating ETo pm_fao56 for station ('OING', '99238')
# Calculating ETo pm_fao56 for station ('OING', '99240')
# Calculating ETo pm_fao56 for station ('OING', '99241')
# Calculating ETo pm_fao56 for station ('OING', '99242')
# Calculating ETo pm_fao56 for station ('OING', '99271')
# Calculating ETo pm_fao56 for station ('OING', '99300')
# Calculating ETo pm_fao56 for station ('OING', '99304')
# Calculating ETo pm_fao56 for station ('OISS', '19575')
# Calculating ETo pm_fao56 for station ('OISS', '19577')
# Calculating ETo pm_fao56 for station ('OISS', '19584')
# Calculating ETo pm_fao56 for station ('OISS', '19622')
# Calculating ETo pm_fao56 for station ('OISS', '19625')
# Calculating ETo pm_fao56 for station ('OISS', '19639')
# Calculating ETo pm_fao56 for station ('OISS', '19653')
# Calculating ETo pm_fao56 for station ('OISS', '19686')
# Calculating ETo pm_fao56 for station ('OISS', '19689')
# Calculating ETo pm_fao56 for station ('OISS', '19690')
# Calculating ETo pm_fao56 for station ('OISS', '19704')
# Calculating ETo pm_fao56 for station ('OISS', '19726')
# Calculating ETo pm_fao56 for station ('OISS', '19739')
# Calculating ETo pm_fao56 for station ('OISS', '19780')
# Calculating ETo pm_fao56 for station ('OISS', '19837')
# Calculating ETo pm_fao56 for station ('OISS', '19845')
# Calculating ETo pm_fao56 for station ('OISS', '19850')
# Calculating ETo pm_fao56 for station ('OISS', '19855')
# Calculating ETo pm_fao56 for station ('OISS', '19858')
# Calculating ETo pm_fao56 for station ('OISS', '19877')
# Calculating ETo pm_fao56 for station ('OISS', '19882')
# Calculating ETo pm_fao56 for station ('OISS', '19889')
# Calculating ETo pm_fao56 for station ('OISS', '19894')
# Calculating ETo pm_fao56 for station ('OISS', '19905')
# Calculating ETo pm_fao56 for station ('OISS', '19915')
# Calculating ETo pm_fao56 for station ('OISS', '19924')
# Calculating ETo pm_fao56 for station ('OISS', '40818')
# Calculating ETo pm_fao56 for station ('OISS', '40828')
# Calculating ETo pm_fao56 for station ('OISS', '40844')
# Calculating ETo pm_fao56 for station ('OISS', '40847')
# Calculating ETo pm_fao56 for station ('OISS', '40848')
# Calculating ETo pm_fao56 for station ('OISS', '40855')
# Calculating ETo pm_fao56 for station ('OISS', '40859')
# Calculating ETo pm_fao56 for station ('OISS', '40861')
# Calculating ETo pm_fao56 for station ('OISS', '40862')
# Calculating ETo pm_fao56 for station ('OISS', '40864')
# Calculating ETo pm_fao56 for station ('OISS', '40869')
# Calculating ETo pm_fao56 for station ('OISS', '40873')
# Calculating ETo pm_fao56 for station ('OISS', '88184')
# Calculating ETo pm_fao56 for station ('OISS', '88190')
# Calculating ETo pm_fao56 for station ('OISS', '90700')
# Calculating ETo pm_fao56 for station ('OISS', '99516')
# Calculating ETo pm_fao56 for station ('OISS', '99561')
# Calculating ETo pm_fao56 for station ('OISS', '99566')
# Calculating ETo pm_fao56 for station ('OISS', '99575')
# Calculating ETo pm_fao56 for station ('OISS', '99579')
# Calculating ETo pm_fao56 for station ('OISS', '99580')
# Calculating ETo pm_fao56 for station ('OISS', '99590')
# Calculating ETo pm_fao56 for station ('OISS', '99597')
# Calculating ETo pm_fao56 for station ('OISS', '99601')
# Calculating ETo pm_fao56 for station ('OISS', '99607')
# Calculating ETo pm_fao56 for station ('OISS', '99612')
# Calculating ETo pm_fao56 for station ('OISS', '99630')
# Calculating ETo pm_fao56 for station ('OISS', '99634')
# Calculating ETo pm_fao56 for station ('OISS', '99638')
# Calculating ETo pm_fao56 for station ('OISS', '99646')
# Calculating ETo pm_fao56 for station ('OISY', '40835')
# Calculating ETo pm_fao56 for station ('OISY', '40836')
# Calculating ETo pm_fao56 for station ('OISY', '40838')
# Calculating ETo pm_fao56 for station ('OISY', '99552')
# Calculating ETo pm_fao56 for station ('OISY', '99555')
# Calculating ETo pm_fao56 for station ('OISY', '99560')
# Calculating ETo pm_fao56 for station ('OISY', '99565')
# Calculating ETo pm_fao56 for station ('OITL', '18011')
# Calculating ETo pm_fao56 for station ('OITL', '18022')
# Calculating ETo pm_fao56 for station ('OITL', '18037')
# Calculating ETo pm_fao56 for station ('OITL', '18043')
# Calculating ETo pm_fao56 for station ('OITL', '18060')
# Calculating ETo pm_fao56 for station ('OITL', '40700')
# Calculating ETo pm_fao56 for station ('OITL', '40705')
# Calculating ETo pm_fao56 for station ('OITL', '40708')
# Calculating ETo pm_fao56 for station ('OITL', '40714')
# Calculating ETo pm_fao56 for station ('OITL', '40717')
# Calculating ETo pm_fao56 for station ('OITL', '88107')
# Calculating ETo pm_fao56 for station ('OITL', '99201')
# Calculating ETo pm_fao56 for station ('OITL', '99202')
# Calculating ETo pm_fao56 for station ('OITL', '99232')
# Calculating ETo pm_fao56 for station ('OITL', '99233')
# Calculating ETo pm_fao56 for station ('OITL', '99263')
# Calculating ETo pm_fao56 for station ('OITR', '18018')
# Calculating ETo pm_fao56 for station ('OITR', '18041')
# Calculating ETo pm_fao56 for station ('OITR', '18087')
# Calculating ETo pm_fao56 for station ('OITR', '18112')
# Calculating ETo pm_fao56 for station ('OITR', '18145')
# Calculating ETo pm_fao56 for station ('OITR', '18288')
# Calculating ETo pm_fao56 for station ('OITR', '18320')
# Calculating ETo pm_fao56 for station ('OITR', '18391')
# Calculating ETo pm_fao56 for station ('OITR', '40701')
# Calculating ETo pm_fao56 for station ('OITR', '40703')
# Calculating ETo pm_fao56 for station ('OITR', '40712')
# Calculating ETo pm_fao56 for station ('OITR', '40722')
# Calculating ETo pm_fao56 for station ('OITR', '40724')
# Calculating ETo pm_fao56 for station ('OITR', '40725')
# Calculating ETo pm_fao56 for station ('OITR', '40726')
# Calculating ETo pm_fao56 for station ('OITR', '40728')
# Calculating ETo pm_fao56 for station ('OITR', '88102')
# Calculating ETo pm_fao56 for station ('OITR', '88104')
# Calculating ETo pm_fao56 for station ('OITR', '99203')
# Calculating ETo pm_fao56 for station ('OITR', '99209')
# Calculating ETo pm_fao56 for station ('OITR', '99214')
# Calculating ETo pm_fao56 for station ('OITR', '99246')
# Calculating ETo pm_fao56 for station ('OITR', '99256')
# Calculating ETo pm_fao56 for station ('OITR', '99278')
# Calculating ETo pm_fao56 for station ('OITR', '99288')
# Calculating ETo pm_fao56 for station ('OITR', '99292')
# Calculating ETo pm_fao56 for station ('OITR', '99314')
# Calculating ETo pm_fao56 for station ('OITR', '99332')
# Calculating ETo pm_fao56 for station ('OITT', '18019')
# Calculating ETo pm_fao56 for station ('OITT', '18026')
# Calculating ETo pm_fao56 for station ('OITT', '18031')
# Calculating ETo pm_fao56 for station ('OITT', '18035')
# Calculating ETo pm_fao56 for station ('OITT', '18038')
# Calculating ETo pm_fao56 for station ('OITT', '18064')
# Calculating ETo pm_fao56 for station ('OITT', '18068')
# Calculating ETo pm_fao56 for station ('OITT', '18097')
# Calculating ETo pm_fao56 for station ('OITT', '18113')
# Calculating ETo pm_fao56 for station ('OITT', '18118')
# Calculating ETo pm_fao56 for station ('OITT', '18152')
# Calculating ETo pm_fao56 for station ('OITT', '18209')
# Calculating ETo pm_fao56 for station ('OITT', '18211')
# Calculating ETo pm_fao56 for station ('OITT', '40702')
# Calculating ETo pm_fao56 for station ('OITT', '40704')
# Calculating ETo pm_fao56 for station ('OITT', '40706')
# Calculating ETo pm_fao56 for station ('OITT', '40707')
# Calculating ETo pm_fao56 for station ('OITT', '40710')
# Calculating ETo pm_fao56 for station ('OITT', '40711')
# Calculating ETo pm_fao56 for station ('OITT', '40713')
# Calculating ETo pm_fao56 for station ('OITT', '40716')
# Calculating ETo pm_fao56 for station ('OITT', '99220')
# Calculating ETo pm_fao56 for station ('OITT', '99226')
# Calculating ETo pm_fao56 for station ('OITT', '99227')
# Calculating ETo pm_fao56 for station ('OITT', '99228')
# Calculating ETo pm_fao56 for station ('OITT', '99234')
# Calculating ETo pm_fao56 for station ('OITT', '99236')
# Calculating ETo pm_fao56 for station ('OITT', '99239')
# Calculating ETo pm_fao56 for station ('OITT', '99244')
# Calculating ETo pm_fao56 for station ('OITT', '99248')
# Calculating ETo pm_fao56 for station ('OITT', '99283')
# Calculating ETo pm_fao56 for station ('OITT', '99284')
# Calculating ETo pm_fao56 for station ('OITZ', '18269')
# Calculating ETo pm_fao56 for station ('OITZ', '18282')
# Calculating ETo pm_fao56 for station ('OITZ', '18285')
# Calculating ETo pm_fao56 for station ('OITZ', '18314')
# Calculating ETo pm_fao56 for station ('OITZ', '18323')
# Calculating ETo pm_fao56 for station ('OITZ', '18333')
# Calculating ETo pm_fao56 for station ('OITZ', '18345')
# Calculating ETo pm_fao56 for station ('OITZ', '18353')
# Calculating ETo pm_fao56 for station ('OITZ', '18409')
# Calculating ETo pm_fao56 for station ('OITZ', '18417')
# Calculating ETo pm_fao56 for station ('OITZ', '18451')
# Calculating ETo pm_fao56 for station ('OITZ', '18454')
# Calculating ETo pm_fao56 for station ('OITZ', '18479')
# Calculating ETo pm_fao56 for station ('OITZ', '18486')
# Calculating ETo pm_fao56 for station ('OITZ', '18496')
# Calculating ETo pm_fao56 for station ('OITZ', '18515')
# Calculating ETo pm_fao56 for station ('OITZ', '18541')
# Calculating ETo pm_fao56 for station ('OITZ', '18589')
# Calculating ETo pm_fao56 for station ('OITZ', '18618')
# Calculating ETo pm_fao56 for station ('OITZ', '18699')
# Calculating ETo pm_fao56 for station ('OITZ', '40715')
# Calculating ETo pm_fao56 for station ('OITZ', '40729')
# Calculating ETo pm_fao56 for station ('OITZ', '40730')
# Calculating ETo pm_fao56 for station ('OITZ', '40733')
# Calculating ETo pm_fao56 for station ('OITZ', '88118')
# Calculating ETo pm_fao56 for station ('OITZ', '99298')
# Calculating ETo pm_fao56 for station ('OITZ', '99312')
# Calculating ETo pm_fao56 for station ('OITZ', '99334')
# Calculating ETo pm_fao56 for station ('OITZ', '99335')
# Calculating ETo pm_fao56 for station ('OIYY', '19298')
# Calculating ETo pm_fao56 for station ('OIYY', '19302')
# Calculating ETo pm_fao56 for station ('OIYY', '19344')
# Calculating ETo pm_fao56 for station ('OIYY', '19345')
# Calculating ETo pm_fao56 for station ('OIYY', '19352')
# Calculating ETo pm_fao56 for station ('OIYY', '19402')
# Calculating ETo pm_fao56 for station ('OIYY', '19408')
# Calculating ETo pm_fao56 for station ('OIYY', '19426')
# Calculating ETo pm_fao56 for station ('OIYY', '19435')
# Calculating ETo pm_fao56 for station ('OIYY', '19438')
# Calculating ETo pm_fao56 for station ('OIYY', '19448')
# Calculating ETo pm_fao56 for station ('OIYY', '19449')
# Calculating ETo pm_fao56 for station ('OIYY', '19483')
# Calculating ETo pm_fao56 for station ('OIYY', '19485')
# Calculating ETo pm_fao56 for station ('OIYY', '19508')
# Calculating ETo pm_fao56 for station ('OIYY', '19510')
# Calculating ETo pm_fao56 for station ('OIYY', '19511')
# Calculating ETo pm_fao56 for station ('OIYY', '19518')
# Calculating ETo pm_fao56 for station ('OIYY', '19567')
# Calculating ETo pm_fao56 for station ('OIYY', '19699')
# Calculating ETo pm_fao56 for station ('OIYY', '40790')
# Calculating ETo pm_fao56 for station ('OIYY', '40804')
# Calculating ETo pm_fao56 for station ('OIYY', '40816')
# Calculating ETo pm_fao56 for station ('OIYY', '40820')
# Calculating ETo pm_fao56 for station ('OIYY', '40821')
# Calculating ETo pm_fao56 for station ('OIYY', '40840')
# Calculating ETo pm_fao56 for station ('OIYY', '99511')
# Calculating ETo pm_fao56 for station ('OIYY', '99522')
# Calculating ETo pm_fao56 for station ('OIYY', '99528')
# Calculating ETo pm_fao56 for station ('OIYY', '99539')
# Calculating ETo pm_fao56 for station ('OIYY', '99574')
# Calculating ETo pm_fao56 for station ('OIZH', '18042')
# Calculating ETo pm_fao56 for station ('OIZH', '19546')
# Calculating ETo pm_fao56 for station ('OIZH', '19574')
# Calculating ETo pm_fao56 for station ('OIZH', '19641')
# Calculating ETo pm_fao56 for station ('OIZH', '19744')
# Calculating ETo pm_fao56 for station ('OIZH', '19809')
# Calculating ETo pm_fao56 for station ('OIZH', '19870')
# Calculating ETo pm_fao56 for station ('OIZH', '19925')
# Calculating ETo pm_fao56 for station ('OIZH', '19942')
# Calculating ETo pm_fao56 for station ('OIZH', '19947')
# Calculating ETo pm_fao56 for station ('OIZH', '19951')
# Calculating ETo pm_fao56 for station ('OIZH', '19974')
# Calculating ETo pm_fao56 for station ('OIZH', '19975')
# Calculating ETo pm_fao56 for station ('OIZH', '19980')
# Calculating ETo pm_fao56 for station ('OIZH', '19992')
# Calculating ETo pm_fao56 for station ('OIZH', '19996')
# Calculating ETo pm_fao56 for station ('OIZH', '19998')
# Calculating ETo pm_fao56 for station ('OIZH', '40829')
# Calculating ETo pm_fao56 for station ('OIZH', '40856')
# Calculating ETo pm_fao56 for station ('OIZH', '40870')
# Calculating ETo pm_fao56 for station ('OIZH', '40874')
# Calculating ETo pm_fao56 for station ('OIZH', '40878')
# Calculating ETo pm_fao56 for station ('OIZH', '40879')
# Calculating ETo pm_fao56 for station ('OIZH', '40885')
# Calculating ETo pm_fao56 for station ('OIZH', '40895')
# Calculating ETo pm_fao56 for station ('OIZH', '40898')
# Calculating ETo pm_fao56 for station ('OIZH', '99586')
# Calculating ETo pm_fao56 for station ('OIZH', '99608')
# Calculating ETo pm_fao56 for station ('OIZH', '99623')
# Calculating ETo pm_fao56 for station ('OIZH', '99649')
# Calculating ETo pm_fao56 for station ('OIZH', '99650')
# Calculating ETo pm_fao56 for station ('QOQM', '18934')
# Calculating ETo pm_fao56 for station ('QOQM', '18946')
# Calculating ETo pm_fao56 for station ('QOQM', '18955')
# Calculating ETo pm_fao56 for station ('QOQM', '18956')
# Calculating ETo pm_fao56 for station ('QOQM', '18958')
# Calculating ETo pm_fao56 for station ('QOQM', '18969')
# Calculating ETo pm_fao56 for station ('QOQM', '18999')
# Calculating ETo pm_fao56 for station ('QOQM', '40770')
# Calculating ETo pm_fao56 for station ('QOQM', '40887')
# Calculating ETo pm_fao56 for station ('QOQM', '99413')
# Calculating ETo pm_fao56 for station ('QOQM', '99414')
# Calculating ETo pm_fao56 for station ('QOQM', '99426')
# Calculating ETo pm_fao56 for station ('QOQM', '99440')
# Calculating ETo hargreaves for station ('ALKK', '18554')
# Calculating ETo hargreaves for station ('ALKK', '18590')
# Calculating ETo hargreaves for station ('ALKK', '18592')
# Calculating ETo hargreaves for station ('ALKK', '18593')
# Calculating ETo hargreaves for station ('ALKK', '18607')
# Calculating ETo hargreaves for station ('ALKK', '18622')
# Calculating ETo hargreaves for station ('ALKK', '18632')
# Calculating ETo hargreaves for station ('ALKK', '18703')
# Calculating ETo hargreaves for station ('ALKK', '18712')
# Calculating ETo hargreaves for station ('ALKK', '40752')
# Calculating ETo hargreaves for station ('ALKK', '75201')
# Calculating ETo hargreaves for station ('ALKK', '88125')
# Calculating ETo hargreaves for station ('ALKK', '90220')
# Calculating ETo hargreaves for station ('ALKK', '99321')
# Calculating ETo hargreaves for station ('ALKK', '99373')
# Calculating ETo hargreaves for station ('ALKK', '99396')
# Calculating ETo hargreaves for station ('MAAA', '18915')
# Calculating ETo hargreaves for station ('MAAA', '18975')
# Calculating ETo hargreaves for station ('MAAA', '19060')
# Calculating ETo hargreaves for station ('MAAA', '40769')
# Calculating ETo hargreaves for station ('MAAA', '40891')
# Calculating ETo hargreaves for station ('MAAA', '88132')
# Calculating ETo hargreaves for station ('MAAA', '99372')
# Calculating ETo hargreaves for station ('MAAA', '99398')
# Calculating ETo hargreaves for station ('MAAA', '99409')
# Calculating ETo hargreaves for station ('MAAA', '99410')
# Calculating ETo hargreaves for station ('MAAA', '99412')
# Calculating ETo hargreaves for station ('MAAA', '99424')
# Calculating ETo hargreaves for station ('MAAA', '99432')
# Calculating ETo hargreaves for station ('MAAA', '99439')
# Calculating ETo hargreaves for station ('MAAA', '99441')
# Calculating ETo hargreaves for station ('MAAA', '99443')
# Calculating ETo hargreaves for station ('MAAA', '99461')
# Calculating ETo hargreaves for station ('MASA', '18332')
# Calculating ETo hargreaves for station ('MASA', '18377')
# Calculating ETo hargreaves for station ('MASA', '18389')
# Calculating ETo hargreaves for station ('MASA', '18410')
# Calculating ETo hargreaves for station ('MASA', '18420')
# Calculating ETo hargreaves for station ('MASA', '18423')
# Calculating ETo hargreaves for station ('MASA', '18488')
# Calculating ETo hargreaves for station ('MASA', '24002')
# Calculating ETo hargreaves for station ('MASA', '40732')
# Calculating ETo hargreaves for station ('MASA', '40734')
# Calculating ETo hargreaves for station ('MASA', '40735')
# Calculating ETo hargreaves for station ('MASA', '40736')
# Calculating ETo hargreaves for station ('MASA', '40737')
# Calculating ETo hargreaves for station ('MASA', '40759')
# Calculating ETo hargreaves for station ('MASA', '40760')
# Calculating ETo hargreaves for station ('MASA', '40788')
# Calculating ETo hargreaves for station ('MASA', '99299')
# Calculating ETo hargreaves for station ('MASA', '99306')
# Calculating ETo hargreaves for station ('MASA', '99308')
# Calculating ETo hargreaves for station ('MASA', '99309')
# Calculating ETo hargreaves for station ('MASA', '99340')
# Calculating ETo hargreaves for station ('MASA', '99348')
# Calculating ETo hargreaves for station ('MASA', '99357')
# Calculating ETo hargreaves for station ('MASA', '99360')
# Calculating ETo hargreaves for station ('MASA', '99361')
# Calculating ETo hargreaves for station ('OIAW', '19478')
# Calculating ETo hargreaves for station ('OIAW', '19497')
# Calculating ETo hargreaves for station ('OIAW', '19499')
# Calculating ETo hargreaves for station ('OIAW', '19569')
# Calculating ETo hargreaves for station ('OIAW', '40794')
# Calculating ETo hargreaves for station ('OIAW', '40795')
# Calculating ETo hargreaves for station ('OIAW', '40810')
# Calculating ETo hargreaves for station ('OIAW', '40811')
# Calculating ETo hargreaves for station ('OIAW', '40812')
# Calculating ETo hargreaves for station ('OIAW', '40813')
# Calculating ETo hargreaves for station ('OIAW', '40830')
# Calculating ETo hargreaves for station ('OIAW', '40831')
# Calculating ETo hargreaves for station ('OIAW', '40832')
# Calculating ETo hargreaves for station ('OIAW', '40833')
# Calculating ETo hargreaves for station ('OIAW', '40834')
# Calculating ETo hargreaves for station ('OIAW', '99446')
# Calculating ETo hargreaves for station ('OIAW', '99455')
# Calculating ETo hargreaves for station ('OIAW', '99456')
# Calculating ETo hargreaves for station ('OIAW', '99493')
# Calculating ETo hargreaves for station ('OIAW', '99508')
# Calculating ETo hargreaves for station ('OIAW', '99513')
# Calculating ETo hargreaves for station ('OIAW', '99514')
# Calculating ETo hargreaves for station ('OIAW', '99527')
# Calculating ETo hargreaves for station ('OIAW', '99535')
# Calculating ETo hargreaves for station ('OIAW', '99537')
# Calculating ETo hargreaves for station ('OIAW', '99538')
# Calculating ETo hargreaves for station ('OIBB', '19749')
# Calculating ETo hargreaves for station ('OIBB', '19751')
# Calculating ETo hargreaves for station ('OIBB', '19775')
# Calculating ETo hargreaves for station ('OIBB', '19779')
# Calculating ETo hargreaves for station ('OIBB', '19799')
# Calculating ETo hargreaves for station ('OIBB', '19851')
# Calculating ETo hargreaves for station ('OIBB', '19862')
# Calculating ETo hargreaves for station ('OIBB', '19865')
# Calculating ETo hargreaves for station ('OIBB', '19880')
# Calculating ETo hargreaves for station ('OIBB', '19886')
# Calculating ETo hargreaves for station ('OIBB', '19958')
# ...
# Calculating ETo hargreaves for station ('OIMN', '18213')
# Calculating ETo hargreaves for station ('OIMN', '18224')
# Calculating ETo hargreaves for station ('OIMN', '18254')
# Calculating ETo hargreaves for station ('OIMN', '18260')
# Calculating ETo hargreaves for station ('OIMN', '18275')
# Calculating ETo hargreaves for station ('OIMN', '18363')
# Calculating ETo hargreaves for station ('OIMN', '40723')
# Calculating ETo hargreaves for station ('OIMN', '99245')
# Calculating ETo hargreaves for station ('OIMN', '99262')
# Calculating ETo hargreaves for station ('OIMN', '99266')
# Calculating ETo hargreaves for station ('OIMN', '99270')
# Calculating ETo hargreaves for station ('OIMN', '99287')
# Calculating ETo hargreaves for station ('OIMN', '99295')
# Calculating ETo hargreaves for station ('OING', '18098')
# Calculating ETo hargreaves for station ('OING', '18134')
# Calculating ETo hargreaves for station ('OING', '18181')
# Calculating ETo hargreaves for station ('OING', '18193')
# Calculating ETo hargreaves for station ('OING', '18255')
# Calculating ETo hargreaves for station ('OING', '18259')
# Calculating ETo hargreaves for station ('OING', '18273')
# Calculating ETo hargreaves for station ('OING', '18280')
# Calculating ETo hargreaves for station ('OING', '18286')
# Calculating ETo hargreaves for station ('OING', '18301')
# Calculating ETo hargreaves for station ('OING', '18326')
# Calculating ETo hargreaves for station ('OING', '18339')
# Calculating ETo hargreaves for station ('OING', '18366')
# Calculating ETo hargreaves for station ('OING', '40721')
# Calculating ETo hargreaves for station ('OING', '40738')
# Calculating ETo hargreaves for station ('OING', '88113')
# Calculating ETo hargreaves for station ('OING', '99237')
# Calculating ETo hargreaves for station ('OING', '99238')
# Calculating ETo hargreaves for station ('OING', '99240')
# Calculating ETo hargreaves for station ('OING', '99241')
# Calculating ETo hargreaves for station ('OING', '99242')
# Calculating ETo hargreaves for station ('OING', '99271')
# Calculating ETo hargreaves for station ('OING', '99300')
# Calculating ETo hargreaves for station ('OING', '99304')
# Calculating ETo hargreaves for station ('OISS', '19575')
# Calculating ETo hargreaves for station ('OISS', '19577')
# Calculating ETo hargreaves for station ('OISS', '19584')
# Calculating ETo hargreaves for station ('OISS', '19622')
# Calculating ETo hargreaves for station ('OISS', '19625')
# Calculating ETo hargreaves for station ('OISS', '19639')
# Calculating ETo hargreaves for station ('OISS', '19653')
# Calculating ETo hargreaves for station ('OISS', '19686')
# Calculating ETo hargreaves for station ('OISS', '19689')
# Calculating ETo hargreaves for station ('OISS', '19690')
# Calculating ETo hargreaves for station ('OISS', '19704')
# Calculating ETo hargreaves for station ('OISS', '19726')
# Calculating ETo hargreaves for station ('OISS', '19739')
# Calculating ETo hargreaves for station ('OISS', '19780')
# Calculating ETo hargreaves for station ('OISS', '19837')
# Calculating ETo hargreaves for station ('OISS', '19845')
# Calculating ETo hargreaves for station ('OISS', '19850')
# Calculating ETo hargreaves for station ('OISS', '19855')
# Calculating ETo hargreaves for station ('OISS', '19858')
# Calculating ETo hargreaves for station ('OISS', '19877')
# Calculating ETo hargreaves for station ('OISS', '19882')
# Calculating ETo hargreaves for station ('OISS', '19889')
# Calculating ETo hargreaves for station ('OISS', '19894')
# Calculating ETo hargreaves for station ('OISS', '19905')
# Calculating ETo hargreaves for station ('OISS', '19915')
# Calculating ETo hargreaves for station ('OISS', '19924')
# Calculating ETo hargreaves for station ('OISS', '40818')
# Calculating ETo hargreaves for station ('OISS', '40828')
# Calculating ETo hargreaves for station ('OISS', '40844')
# Calculating ETo hargreaves for station ('OISS', '40847')
# Calculating ETo hargreaves for station ('OISS', '40848')
# Calculating ETo hargreaves for station ('OISS', '40855')
# Calculating ETo hargreaves for station ('OISS', '40859')
# Calculating ETo hargreaves for station ('OISS', '40861')
# Calculating ETo hargreaves for station ('OISS', '40862')
# Calculating ETo hargreaves for station ('OISS', '40864')
# Calculating ETo hargreaves for station ('OISS', '40869')
# Calculating ETo hargreaves for station ('OISS', '40873')
# Calculating ETo hargreaves for station ('OISS', '88184')
# Calculating ETo hargreaves for station ('OISS', '88190')
# Calculating ETo hargreaves for station ('OISS', '90700')
# Calculating ETo hargreaves for station ('OISS', '99516')
# Calculating ETo hargreaves for station ('OISS', '99561')
# Calculating ETo hargreaves for station ('OISS', '99566')
# Calculating ETo hargreaves for station ('OISS', '99575')
# Calculating ETo hargreaves for station ('OISS', '99579')
# Calculating ETo hargreaves for station ('OISS', '99580')
# Calculating ETo hargreaves for station ('OISS', '99590')
# Calculating ETo hargreaves for station ('OISS', '99597')
# Calculating ETo hargreaves for station ('OISS', '99601')
# Calculating ETo hargreaves for station ('OISS', '99607')
# Calculating ETo hargreaves for station ('OISS', '99612')
# Calculating ETo hargreaves for station ('OISS', '99630')
# Calculating ETo hargreaves for station ('OISS', '99634')
# Calculating ETo hargreaves for station ('OISS', '99638')
# Calculating ETo hargreaves for station ('OISS', '99646')
# Calculating ETo hargreaves for station ('OISY', '40835')
# Calculating ETo hargreaves for station ('OISY', '40836')
# Calculating ETo hargreaves for station ('OISY', '40838')
# Calculating ETo hargreaves for station ('OISY', '99552')
# Calculating ETo hargreaves for station ('OISY', '99555')
# Calculating ETo hargreaves for station ('OISY', '99560')
# Calculating ETo hargreaves for station ('OISY', '99565')
# Calculating ETo hargreaves for station ('OITL', '18011')
# Calculating ETo hargreaves for station ('OITL', '18022')
# Calculating ETo hargreaves for station ('OITL', '18037')
# Calculating ETo hargreaves for station ('OITL', '18043')
# Calculating ETo hargreaves for station ('OITL', '18060')
# Calculating ETo hargreaves for station ('OITL', '40700')
# Calculating ETo hargreaves for station ('OITL', '40705')
# Calculating ETo hargreaves for station ('OITL', '40708')
# Calculating ETo hargreaves for station ('OITL', '40714')
# Calculating ETo hargreaves for station ('OITL', '40717')
# Calculating ETo hargreaves for station ('OITL', '88107')
# Calculating ETo hargreaves for station ('OITL', '99201')
# Calculating ETo hargreaves for station ('OITL', '99202')
# Calculating ETo hargreaves for station ('OITL', '99232')
# Calculating ETo hargreaves for station ('OITL', '99233')
# Calculating ETo hargreaves for station ('OITL', '99263')
# Calculating ETo hargreaves for station ('OITR', '18018')
# Calculating ETo hargreaves for station ('OITR', '18041')
# Calculating ETo hargreaves for station ('OITR', '18087')
# Calculating ETo hargreaves for station ('OITR', '18112')
# Calculating ETo hargreaves for station ('OITR', '18145')
# Calculating ETo hargreaves for station ('OITR', '18288')
# Calculating ETo hargreaves for station ('OITR', '18320')
# Calculating ETo hargreaves for station ('OITR', '18391')
# Calculating ETo hargreaves for station ('OITR', '40701')
# Calculating ETo hargreaves for station ('OITR', '40703')
# Calculating ETo hargreaves for station ('OITR', '40712')
# Calculating ETo hargreaves for station ('OITR', '40722')
# Calculating ETo hargreaves for station ('OITR', '40724')
# Calculating ETo hargreaves for station ('OITR', '40725')
# Calculating ETo hargreaves for station ('OITR', '40726')
# Calculating ETo hargreaves for station ('OITR', '40728')
# Calculating ETo hargreaves for station ('OITR', '88102')
# Calculating ETo hargreaves for station ('OITR', '88104')
# Calculating ETo hargreaves for station ('OITR', '99203')
# Calculating ETo hargreaves for station ('OITR', '99209')
# Calculating ETo hargreaves for station ('OITR', '99214')
# Calculating ETo hargreaves for station ('OITR', '99246')
# Calculating ETo hargreaves for station ('OITR', '99256')
# Calculating ETo hargreaves for station ('OITR', '99278')
# Calculating ETo hargreaves for station ('OITR', '99288')
# Calculating ETo hargreaves for station ('OITR', '99292')
# Calculating ETo hargreaves for station ('OITR', '99314')
# Calculating ETo hargreaves for station ('OITR', '99332')
# Calculating ETo hargreaves for station ('OITT', '18019')
# Calculating ETo hargreaves for station ('OITT', '18026')
# Calculating ETo hargreaves for station ('OITT', '18031')
# Calculating ETo hargreaves for station ('OITT', '18035')
# Calculating ETo hargreaves for station ('OITT', '18038')
# Calculating ETo hargreaves for station ('OITT', '18064')
# Calculating ETo hargreaves for station ('OITT', '18068')
# Calculating ETo hargreaves for station ('OITT', '18097')
# Calculating ETo hargreaves for station ('OITT', '18113')
# Calculating ETo hargreaves for station ('OITT', '18118')
# Calculating ETo hargreaves for station ('OITT', '18152')
# Calculating ETo hargreaves for station ('OITT', '18209')
# Calculating ETo hargreaves for station ('OITT', '18211')
# Calculating ETo hargreaves for station ('OITT', '40702')
# Calculating ETo hargreaves for station ('OITT', '40704')
# Calculating ETo hargreaves for station ('OITT', '40706')
# Calculating ETo hargreaves for station ('OITT', '40707')
# Calculating ETo hargreaves for station ('OITT', '40710')
# Calculating ETo hargreaves for station ('OITT', '40711')
# Calculating ETo hargreaves for station ('OITT', '40713')
# Calculating ETo hargreaves for station ('OITT', '40716')
# Calculating ETo hargreaves for station ('OITT', '99220')
# Calculating ETo hargreaves for station ('OITT', '99226')
# Calculating ETo hargreaves for station ('OITT', '99227')
# Calculating ETo hargreaves for station ('OITT', '99228')
# Calculating ETo hargreaves for station ('OITT', '99234')
# Calculating ETo hargreaves for station ('OITT', '99236')
# Calculating ETo hargreaves for station ('OITT', '99239')
# Calculating ETo hargreaves for station ('OITT', '99244')
# Calculating ETo hargreaves for station ('OITT', '99248')
# Calculating ETo hargreaves for station ('OITT', '99283')
# Calculating ETo hargreaves for station ('OITT', '99284')
# Calculating ETo hargreaves for station ('OITZ', '18269')
# Calculating ETo hargreaves for station ('OITZ', '18282')
# Calculating ETo hargreaves for station ('OITZ', '18285')
# Calculating ETo hargreaves for station ('OITZ', '18314')
# Calculating ETo hargreaves for station ('OITZ', '18323')
# Calculating ETo hargreaves for station ('OITZ', '18333')
# Calculating ETo hargreaves for station ('OITZ', '18345')
# Calculating ETo hargreaves for station ('OITZ', '18353')
# Calculating ETo hargreaves for station ('OITZ', '18409')
# Calculating ETo hargreaves for station ('OITZ', '18417')
# Calculating ETo hargreaves for station ('OITZ', '18451')
# Calculating ETo hargreaves for station ('OITZ', '18454')
# Calculating ETo hargreaves for station ('OITZ', '18479')
# Calculating ETo hargreaves for station ('OITZ', '18486')
# Calculating ETo hargreaves for station ('OITZ', '18496')
# Calculating ETo hargreaves for station ('OITZ', '18515')
# Calculating ETo hargreaves for station ('OITZ', '18541')
# Calculating ETo hargreaves for station ('OITZ', '18589')
# Calculating ETo hargreaves for station ('OITZ', '18618')
# Calculating ETo hargreaves for station ('OITZ', '18699')
# Calculating ETo hargreaves for station ('OITZ', '40715')
# Calculating ETo hargreaves for station ('OITZ', '40729')
# Calculating ETo hargreaves for station ('OITZ', '40730')
# Calculating ETo hargreaves for station ('OITZ', '40733')
# Calculating ETo hargreaves for station ('OITZ', '88118')
# Calculating ETo hargreaves for station ('OITZ', '99298')
# Calculating ETo hargreaves for station ('OITZ', '99312')
# Calculating ETo hargreaves for station ('OITZ', '99334')
# Calculating ETo hargreaves for station ('OITZ', '99335')
# Calculating ETo hargreaves for station ('OIYY', '19298')
# Calculating ETo hargreaves for station ('OIYY', '19302')
# Calculating ETo hargreaves for station ('OIYY', '19344')
# Calculating ETo hargreaves for station ('OIYY', '19345')
# Calculating ETo hargreaves for station ('OIYY', '19352')
# Calculating ETo hargreaves for station ('OIYY', '19402')
# Calculating ETo hargreaves for station ('OIYY', '19408')
# Calculating ETo hargreaves for station ('OIYY', '19426')
# Calculating ETo hargreaves for station ('OIYY', '19435')
# Calculating ETo hargreaves for station ('OIYY', '19438')
# Calculating ETo hargreaves for station ('OIYY', '19448')
# Calculating ETo hargreaves for station ('OIYY', '19449')
# Calculating ETo hargreaves for station ('OIYY', '19483')
# Calculating ETo hargreaves for station ('OIYY', '19485')
# Calculating ETo hargreaves for station ('OIYY', '19508')
# Calculating ETo hargreaves for station ('OIYY', '19510')
# Calculating ETo hargreaves for station ('OIYY', '19511')
# Calculating ETo hargreaves for station ('OIYY', '19518')
# Calculating ETo hargreaves for station ('OIYY', '19567')
# Calculating ETo hargreaves for station ('OIYY', '19699')
# Calculating ETo hargreaves for station ('OIYY', '40790')
# Calculating ETo hargreaves for station ('OIYY', '40804')
# Calculating ETo hargreaves for station ('OIYY', '40816')
# Calculating ETo hargreaves for station ('OIYY', '40820')
# Calculating ETo hargreaves for station ('OIYY', '40821')
# Calculating ETo hargreaves for station ('OIYY', '40840')
# Calculating ETo hargreaves for station ('OIYY', '99511')
# Calculating ETo hargreaves for station ('OIYY', '99522')
# Calculating ETo hargreaves for station ('OIYY', '99528')
# Calculating ETo hargreaves for station ('OIYY', '99539')
# Calculating ETo hargreaves for station ('OIYY', '99574')
# Calculating ETo hargreaves for station ('OIZH', '18042')
# Calculating ETo hargreaves for station ('OIZH', '19546')
# Calculating ETo hargreaves for station ('OIZH', '19574')
# Calculating ETo hargreaves for station ('OIZH', '19641')
# Calculating ETo hargreaves for station ('OIZH', '19744')
# Calculating ETo hargreaves for station ('OIZH', '19809')
# Calculating ETo hargreaves for station ('OIZH', '19870')
# Calculating ETo hargreaves for station ('OIZH', '19925')
# Calculating ETo hargreaves for station ('OIZH', '19942')
# Calculating ETo hargreaves for station ('OIZH', '19947')
# Calculating ETo hargreaves for station ('OIZH', '19951')
# Calculating ETo hargreaves for station ('OIZH', '19974')
# Calculating ETo hargreaves for station ('OIZH', '19975')
# Calculating ETo hargreaves for station ('OIZH', '19980')
# Calculating ETo hargreaves for station ('OIZH', '19992')
# Calculating ETo hargreaves for station ('OIZH', '19996')
# Calculating ETo hargreaves for station ('OIZH', '19998')
# Calculating ETo hargreaves for station ('OIZH', '40829')
# Calculating ETo hargreaves for station ('OIZH', '40856')
# Calculating ETo hargreaves for station ('OIZH', '40870')
# Calculating ETo hargreaves for station ('OIZH', '40874')
# Calculating ETo hargreaves for station ('OIZH', '40878')
# Calculating ETo hargreaves for station ('OIZH', '40879')
# Calculating ETo hargreaves for station ('OIZH', '40885')
# Calculating ETo hargreaves for station ('OIZH', '40895')
# Calculating ETo hargreaves for station ('OIZH', '40898')
# Calculating ETo hargreaves for station ('OIZH', '99586')
# Calculating ETo hargreaves for station ('OIZH', '99608')
# Calculating ETo hargreaves for station ('OIZH', '99623')
# Calculating ETo hargreaves for station ('OIZH', '99649')
# Calculating ETo hargreaves for station ('OIZH', '99650')
# Calculating ETo hargreaves for station ('QOQM', '18934')
# Calculating ETo hargreaves for station ('QOQM', '18946')
# Calculating ETo hargreaves for station ('QOQM', '18955')
# Calculating ETo hargreaves for station ('QOQM', '18956')
# Calculating ETo hargreaves for station ('QOQM', '18958')
# Calculating ETo hargreaves for station ('QOQM', '18969')
# Calculating ETo hargreaves for station ('QOQM', '18999')
# Calculating ETo hargreaves for station ('QOQM', '40770')
# Calculating ETo hargreaves for station ('QOQM', '40887')
# Calculating ETo hargreaves for station ('QOQM', '99413')
# Calculating ETo hargreaves for station ('QOQM', '99414')
# Calculating ETo hargreaves for station ('QOQM', '99426')
# Calculating ETo hargreaves for station ('QOQM', '99440')

# %% [markdown]
# #### Join ETo with Original Data

# %%
data
# Out:
#         station_id    station_name region_id region_name   lat   lon  \
# 0            40753  Dowshan Tappeh      OIID    Airforce 35.70 51.48
# 1            40753  Dowshan Tappeh      OIID    Airforce 35.70 51.48
# 2            40753  Dowshan Tappeh      OIID    Airforce 35.70 51.48
# 3            40753  Dowshan Tappeh      OIID    Airforce 35.70 51.48
# 4            40753  Dowshan Tappeh      OIID    Airforce 35.70 51.48
# ...            ...             ...       ...         ...   ...   ...
# 4928057      18699      Zarrenrood      OITZ      Zanjan 35.75 48.48
# 4928058      18699      Zarrenrood      OITZ      Zanjan 35.75 48.48
# 4928059      18699      Zarrenrood      OITZ      Zanjan 35.75 48.48
# 4928060      18699      Zarrenrood      OITZ      Zanjan 35.75 48.48
# 4928061      18699      Zarrenrood      OITZ      Zanjan 35.75 48.48
#
#          station_elevation                date  tmax  tmin    tm  umax  umin  \
# 0                  1209.20 1972-04-01 12:00:00 19.00  7.00 13.00 52.00 23.00
# 1                  1209.20 1972-04-02 12:00:00 13.00  9.00 11.00 62.00 39.00
# 2                  1209.20 1972-04-03 12:00:00 17.00  3.00 10.00 79.00 15.00
# 3                  1209.20 1972-04-04 12:00:00 20.00  9.00 14.50 55.00 23.00
# 4                  1209.20 1972-04-05 12:00:00 18.00  7.00 12.50 81.00 31.00
# ...                    ...                 ...   ...   ...   ...   ...   ...
# 4928057            1751.00 2025-08-18 12:00:00 38.00 18.30 28.15   NaN   NaN
# 4928058            1751.00 2025-08-19 12:00:00 35.10   NaN   NaN   NaN   NaN
# 4928059            1751.00 2025-08-20 12:00:00 37.00   NaN   NaN   NaN   NaN
# 4928060            1751.00 2025-09-03 12:00:00 33.60   NaN   NaN   NaN   NaN
# 4928061            1751.00 2025-09-04 12:00:00 29.60 17.90 23.75   NaN   NaN
#
#            um  ffm  sshn  rrr24
# 0       30.60 3.60 10.80   0.00
# 1       50.20 2.80  0.50   0.10
# 2       40.00 4.20 11.00   1.00
# 3       36.00 3.00  5.00   0.01
# 4       52.20 3.60 11.20   7.00
# ...       ...  ...   ...    ...
# 4928057   NaN  NaN   NaN   0.00
# 4928058   NaN  NaN   NaN   0.00
# 4928059   NaN  NaN   NaN   0.00
# 4928060   NaN  NaN   NaN   0.00
# 4928061   NaN  NaN   NaN    NaN
#
# [4928062 rows x 17 columns]

# %%
if isinstance(eto_df_pm_fao56.index, pd.MultiIndex):
    eto_df_pm_fao56 = eto_df_pm_fao56.reset_index().rename(columns={0:'FAO56'})
    data = pd.merge(data, eto_df_pm_fao56, on=['region_id', 'station_id', 'date'], how='left')
else:
    data = data.join(eto_df_pm_fao56)

if isinstance(eto_df_hargreaves.index, pd.MultiIndex):
    eto_df_hargreaves = eto_df_hargreaves.reset_index().rename(columns={0:'Hargreaves'})
    data = pd.merge(data, eto_df_hargreaves, on=['region_id', 'station_id', 'date'], how='left')
else:
    data = data.join(eto_df_hargreaves)

data
# Out:
#         station_id    station_name region_id region_name   lat   lon  \
# 0            40753  Dowshan Tappeh      OIID    Airforce 35.70 51.48
# 1            40753  Dowshan Tappeh      OIID    Airforce 35.70 51.48
# 2            40753  Dowshan Tappeh      OIID    Airforce 35.70 51.48
# 3            40753  Dowshan Tappeh      OIID    Airforce 35.70 51.48
# 4            40753  Dowshan Tappeh      OIID    Airforce 35.70 51.48
# ...            ...             ...       ...         ...   ...   ...
# 4929099      18699      Zarrenrood      OITZ      Zanjan 35.75 48.48
# 4929100      18699      Zarrenrood      OITZ      Zanjan 35.75 48.48
# 4929101      18699      Zarrenrood      OITZ      Zanjan 35.75 48.48
# 4929102      18699      Zarrenrood      OITZ      Zanjan 35.75 48.48
# 4929103      18699      Zarrenrood      OITZ      Zanjan 35.75 48.48
#
#          station_elevation                date  tmax  tmin    tm  umax  umin  \
# 0                  1209.20 1972-04-01 12:00:00 19.00  7.00 13.00 52.00 23.00
# 1                  1209.20 1972-04-02 12:00:00 13.00  9.00 11.00 62.00 39.00
# 2                  1209.20 1972-04-03 12:00:00 17.00  3.00 10.00 79.00 15.00
# 3                  1209.20 1972-04-04 12:00:00 20.00  9.00 14.50 55.00 23.00
# 4                  1209.20 1972-04-05 12:00:00 18.00  7.00 12.50 81.00 31.00
# ...                    ...                 ...   ...   ...   ...   ...   ...
# 4929099            1751.00 2025-08-18 12:00:00 38.00 18.30 28.15   NaN   NaN
# 4929100            1751.00 2025-08-19 12:00:00 35.10   NaN   NaN   NaN   NaN
# 4929101            1751.00 2025-08-20 12:00:00 37.00   NaN   NaN   NaN   NaN
# 4929102            1751.00 2025-09-03 12:00:00 33.60   NaN   NaN   NaN   NaN
# 4929103            1751.00 2025-09-04 12:00:00 29.60 17.90 23.75   NaN   NaN
#
#            um  ffm  sshn  rrr24  FAO56  Hargreaves
# 0       30.60 3.60 10.80   0.00   4.63        3.30
# 1       50.20 2.80  0.50   0.10   2.71        1.79
# 2       40.00 4.20 11.00   1.00   3.64        3.24
# 3       36.00 3.00  5.00   0.01   4.02        3.38
# 4       52.20 3.60 11.20   7.00   3.76        3.18
# ...       ...  ...   ...    ...    ...         ...
# 4929099   NaN  NaN   NaN   0.00    NaN        7.11
# 4929100   NaN  NaN   NaN   0.00    NaN         NaN
# 4929101   NaN  NaN   NaN   0.00    NaN         NaN
# 4929102   NaN  NaN   NaN   0.00    NaN         NaN
# 4929103   NaN  NaN   NaN    NaN    NaN        4.52
#
# [4929104 rows x 19 columns]

# %% [markdown]
# #### Fill Missing Dates

# %%
# Fill missing dates for each station with NaN
all_dates = pd.date_range(data['date'].min(), data['date'].max(), freq='D')

def reindex_station(station_df):
    print(f"Reindexing station {station_df['station_id'].iloc[0]}")
    print(station_df)
    return station_df.drop_duplicates().set_index('date').reindex(all_dates).assign(
        region_id=station_df['region_id'].iloc[0],
        region_name=station_df['region_name'].iloc[0],
        station_id=station_df['station_id'].iloc[0],
        station_name=station_df['station_name'].iloc[0],
        station_elevation=station_df['station_elevation'].iloc[0],
        lat=station_df['lat'].iloc[0],
        lon=station_df['lon'].iloc[0],
    ).reset_index().rename(columns={'index': 'date'})

result = (
    data.groupby(['region_id', 'region_name', 'station_id', 'station_name', 'station_elevation', 'lat', 'lon'], group_keys=False)
    .apply(reindex_station)
    .reset_index(drop=True)
)

result
# Out:
# Reindexing station 18554
#        station_id       station_name region_id region_name   lat   lon  \
# 110432      18554  Zidashte Taleghan      ALKK      Alborz 36.13 50.68
# 110433      18554  Zidashte Taleghan      ALKK      Alborz 36.13 50.68
# 110434      18554  Zidashte Taleghan      ALKK      Alborz 36.13 50.68
# 110435      18554  Zidashte Taleghan      ALKK      Alborz 36.13 50.68
# 110436      18554  Zidashte Taleghan      ALKK      Alborz 36.13 50.68
# ...           ...                ...       ...         ...   ...   ...
# 111290      18554  Zidashte Taleghan      ALKK      Alborz 36.13 50.68
# 111291      18554  Zidashte Taleghan      ALKK      Alborz 36.13 50.68
# 111292      18554  Zidashte Taleghan      ALKK      Alborz 36.13 50.68
# 111293      18554  Zidashte Taleghan      ALKK      Alborz 36.13 50.68
# 111294      18554  Zidashte Taleghan      ALKK      Alborz 36.13 50.68
#
#         station_elevation                date  tmax  tmin    tm  umax  umin  \
# 110432            2255.00 2023-01-01 12:00:00  2.70 -7.90 -2.60   NaN   NaN
# 110433            2255.00 2023-01-02 12:00:00  2.60 -7.60 -2.50   NaN   NaN
# 110434            2255.00 2023-01-03 12:00:00  5.10 -4.50  0.30   NaN   NaN
# 110435            2255.00 2023-01-04 12:00:00  5.00 -3.70  0.65   NaN   NaN
# 110436            2255.00 2023-01-05 12:00:00  3.60 -4.00 -0.20   NaN   NaN
# ...                   ...                 ...   ...   ...   ...   ...   ...
# 111290            2255.00 2025-07-14 12:00:00 22.50 15.50 19.00   NaN   NaN
# 111291            2255.00 2025-07-18 12:00:00 31.20 18.90 25.05   NaN   NaN
# 111292            2255.00 2025-07-19 12:00:00 28.20 18.50 23.35   NaN   NaN
# 111293            2255.00 2025-07-25 12:00:00 27.40 25.30 26.35   NaN   NaN
# 111294            2255.00 2025-07-26 12:00:00 25.30 16.40 20.85   NaN   NaN
#
#         um  ffm  sshn  rrr24  FAO56  Hargreaves
# 110432 NaN  NaN   NaN   0.00    NaN        0.74
# 110433 NaN  NaN   NaN   0.00    NaN        0.73
# 110434 NaN  NaN   NaN   0.00    NaN        0.84
# 110435 NaN  NaN   NaN   0.00    NaN        0.82
# 110436 NaN  NaN   NaN   2.60    NaN        0.73
# ...     ..  ...   ...    ...    ...         ...
# 111290 NaN  NaN   NaN   1.20    NaN        3.73
# 111291 NaN  NaN   NaN   0.00    NaN        5.74
# 111292 NaN  NaN   NaN   0.00    NaN        4.88
# 111293 NaN  NaN   NaN    NaN    NaN        2.41
# 111294 NaN  NaN   NaN   0.00    NaN        4.31
#
# [863 rows x 19 columns]
# Reindexing station 18590
#       station_id station_name region_id region_name   lat   lon  \
# 58466      18590        Asara      ALKK      Alborz 36.04 51.19
# 58467      18590        Asara      ALKK      Alborz 36.04 51.19
# 58468      18590        Asara      ALKK      Alborz 36.04 51.19
# 58469      18590        Asara      ALKK      Alborz 36.04 51.19
# 58470      18590        Asara      ALKK      Alborz 36.04 51.19
# ...          ...          ...       ...         ...   ...   ...
# 59403      18590        Asara      ALKK      Alborz 36.04 51.19
# 59404      18590        Asara      ALKK      Alborz 36.04 51.19
# 59405      18590        Asara      ALKK      Alborz 36.04 51.19
# 59406      18590        Asara      ALKK      Alborz 36.04 51.19
# 59407      18590        Asara      ALKK      Alborz 36.04 51.19
#
#        station_elevation                date  tmax  tmin    tm  umax  umin  \
# 58466            1864.00 2023-01-01 12:00:00  9.30 -9.40 -0.05   NaN   NaN
# 58467            1864.00 2023-01-02 12:00:00  9.90 -9.60  0.15   NaN   NaN
# 58468            1864.00 2023-01-03 12:00:00 12.10 -8.70  1.70   NaN   NaN
# 58469            1864.00 2023-01-04 12:00:00  9.50 -9.00  0.25   NaN   NaN
# 58470            1864.00 2023-01-05 12:00:00  3.60 -1.30  1.15   NaN   NaN
# ...                  ...                 ...   ...   ...   ...   ...   ...
# 59403            1864.00 2025-09-17 12:00:00 28.40 12.10 20.25   NaN   NaN
# 59404            1864.00 2025-09-18 12:00:00 28.80  9.00 18.90   NaN   NaN
# 59405            1864.00 2025-09-19 12:00:00 31.40  9.60 20.50   NaN   NaN
# 59406            1864.00 2025-09-20 12:00:00 23.80 20.30 22.05   NaN   NaN
# 59407            1864.00 2025-09-21 12:00:00 25.60  8.20 16.90   NaN   NaN
#
#        um  ffm  sshn  rrr24  FAO56  Hargreaves
# 58466 NaN  NaN   NaN   0.00    NaN        1.15
# 58467 NaN  NaN   NaN   0.00    NaN        1.19
# 58468 NaN  NaN   NaN   0.00    NaN        1.34
# 58469 NaN  NaN   NaN   0.00    NaN        1.18
# 58470 NaN  NaN   NaN   6.60    NaN        0.64
# ...    ..  ...   ...    ...    ...         ...
# 59403 NaN  NaN   NaN   0.00    NaN        4.46
# 59404 NaN  NaN   NaN   0.00    NaN        4.70
# 59405 NaN  NaN   NaN   0.00    NaN        5.11
# 59406 NaN  NaN   NaN   0.00    NaN        2.12
# 59407 NaN  NaN   NaN   0.00    NaN        4.06
#
# [942 rows x 19 columns]
# Reindexing station 18592
#       station_id station_name region_id region_name   lat   lon  \
# 59408      18592   Dizin Bala      ALKK      Alborz 36.03 51.43
# 59409      18592   Dizin Bala      ALKK      Alborz 36.03 51.43
# 59410      18592   Dizin Bala      ALKK      Alborz 36.03 51.43
# 59411      18592   Dizin Bala      ALKK      Alborz 36.03 51.43
# 59412      18592   Dizin Bala      ALKK      Alborz 36.03 51.43
# ...          ...          ...       ...         ...   ...   ...
# 59969      18592   Dizin Bala      ALKK      Alborz 36.03 51.43
# 59970      18592   Dizin Bala      ALKK      Alborz 36.03 51.43
# 59971      18592   Dizin Bala      ALKK      Alborz 36.03 51.43
# 59972      18592   Dizin Bala      ALKK      Alborz 36.03 51.43
# 59973      18592   Dizin Bala      ALKK      Alborz 36.03 51.43
#
#        station_elevation                date  tmax   tmin    tm  umax  umin  \
# 59408            3328.00 2023-01-01 12:00:00 -4.40 -10.10 -7.25   NaN   NaN
# 59409            3328.00 2023-01-02 12:00:00  2.50  -9.60 -3.55   NaN   NaN
# 59410            3328.00 2023-01-03 12:00:00  1.50  -5.70 -2.10   NaN   NaN
# 59411            3328.00 2023-01-04 12:00:00 -2.70  -7.20 -4.95   NaN   NaN
# 59412            3328.00 2023-01-05 12:00:00 -3.30  -7.50 -5.40   NaN   NaN
# ...                  ...                 ...   ...    ...   ...   ...   ...
# 59969            3328.00 2025-09-17 12:00:00 16.30   6.60 11.45   NaN   NaN
# 59970            3328.00 2025-09-18 12:00:00 16.10   7.00 11.55   NaN   NaN
# 59971            3328.00 2025-09-19 12:00:00 17.20   7.30 12.25   NaN   NaN
# 59972            3328.00 2025-09-20 12:00:00 14.20   5.70  9.95   NaN   NaN
# 59973            3328.00 2025-09-21 12:00:00 12.90   4.30  8.60   NaN   NaN
#
#        um  ffm  sshn  rrr24  FAO56  Hargreaves
# 59408 NaN  NaN   NaN   0.00    NaN        0.37
# 59409 NaN  NaN   NaN   0.00    NaN        0.74
# 59410 NaN  NaN   NaN   0.00    NaN        0.63
# 59411 NaN  NaN   NaN   0.00    NaN        0.41
# 59412 NaN  NaN   NaN   1.10    NaN        0.38
# ...    ..  ...   ...    ...    ...         ...
# 59969 NaN  NaN   NaN   0.00    NaN        2.62
# 59970 NaN  NaN   NaN   0.00    NaN        2.53
# 59971 NaN  NaN   NaN   0.00    NaN        2.68
# 59972 NaN  NaN   NaN   0.00    NaN        2.27
# 59973 NaN  NaN   NaN   0.00    NaN        2.16
#
# [566 rows x 19 columns]
# Reindexing station 18593
#       station_id      station_name region_id region_name   lat   lon  \
# 93768      18593  Pistechamandizin      ALKK      Alborz 36.05 51.42
# 93769      18593  Pistechamandizin      ALKK      Alborz 36.05 51.42
# 93770      18593  Pistechamandizin      ALKK      Alborz 36.05 51.42
# 93771      18593  Pistechamandizin      ALKK      Alborz 36.05 51.42
# 93772      18593  Pistechamandizin      ALKK      Alborz 36.05 51.42
# ...          ...               ...       ...         ...   ...   ...
# 94709      18593  Pistechamandizin      ALKK      Alborz 36.05 51.42
# 94710      18593  Pistechamandizin      ALKK      Alborz 36.05 51.42
# 94711      18593  Pistechamandizin      ALKK      Alborz 36.05 51.42
# 94712      18593  Pistechamandizin      ALKK      Alborz 36.05 51.42
# 94713      18593  Pistechamandizin      ALKK      Alborz 36.05 51.42
#
#        station_elevation                date  tmax   tmin    tm  umax  umin  \
# 93768            2692.00 2023-01-01 12:00:00 -0.10 -11.30 -5.70   NaN   NaN
# 93769            2692.00 2023-01-02 12:00:00  0.40 -11.00 -5.30   NaN   NaN
# 93770            2692.00 2023-01-03 12:00:00  4.20  -6.20 -1.00   NaN   NaN
# 93771            2692.00 2023-01-04 12:00:00  2.20  -7.60 -2.70   NaN   NaN
# 93772            2692.00 2023-01-05 12:00:00  2.30  -3.80 -0.75   NaN   NaN
# ...                  ...                 ...   ...    ...   ...   ...   ...
# 94709            2692.00 2025-09-17 12:00:00 21.40  11.40 16.40   NaN   NaN
# 94710            2692.00 2025-09-18 12:00:00 20.90  10.80 15.85   NaN   NaN
# 94711            2692.00 2025-09-19 12:00:00 22.40  12.40 17.40   NaN   NaN
# 94712            2692.00 2025-09-20 12:00:00 16.50  12.80 14.65   NaN   NaN
# 94713            2692.00 2025-09-21 12:00:00 17.70   4.80 11.25   NaN   NaN
#
#        um  ffm  sshn  rrr24  FAO56  Hargreaves
# 93768 NaN  NaN   NaN   0.00    NaN        0.60
# 93769 NaN  NaN   NaN   0.00    NaN        0.63
# 93770 NaN  NaN   NaN   0.00    NaN        0.82
# 93771 NaN  NaN   NaN   0.00    NaN        0.71
# 93772 NaN  NaN   NaN   0.00    NaN        0.64
# ...    ..  ...   ...    ...    ...         ...
# 94709 NaN  NaN   NaN   0.00    NaN        3.13
# 94710 NaN  NaN   NaN   0.00    NaN        3.07
# 94711 NaN  NaN   NaN   0.40    NaN        3.17
# 94712 NaN  NaN   NaN    NaN    NaN        1.76
# 94713 NaN  NaN   NaN   0.00    NaN        2.91
#
# [946 rows x 19 columns]
# Reindexing station 18607
#        station_id  station_name region_id region_name   lat   lon  \
# 95679       18607  Shahrestanak      ALKK      Alborz 35.97 51.36
# 95680       18607  Shahrestanak      ALKK      Alborz 35.97 51.36
# 95681       18607  Shahrestanak      ALKK      Alborz 35.97 51.36
# 95682       18607  Shahrestanak      ALKK      Alborz 35.97 51.36
# 95683       18607  Shahrestanak      ALKK      Alborz 35.97 51.36
# ...           ...           ...       ...         ...   ...   ...
# 103954      18607  Shahrestanak      ALKK      Alborz 35.97 51.36
# 103955      18607  Shahrestanak      ALKK      Alborz 35.97 51.36
# 103956      18607  Shahrestanak      ALKK      Alborz 35.97 51.36
# 103957      18607  Shahrestanak      ALKK      Alborz 35.97 51.36
# 103958      18607  Shahrestanak      ALKK      Alborz 35.97 51.36
#
#         station_elevation                date  tmax   tmin    tm  umax  umin  \
# 95679             2200.00 1957-12-01 12:00:00 10.00  -4.40  2.80   NaN   NaN
# 95680             2200.00 1957-12-02 12:00:00  8.90  -8.90  0.00   NaN   NaN
# 95681             2200.00 1957-12-03 12:00:00 10.00 -10.00  0.00   NaN   NaN
# 95682             2200.00 1957-12-04 12:00:00  6.70 -10.00 -1.65   NaN   NaN
# 95683             2200.00 1957-12-05 12:00:00 13.30  -8.90  2.20   NaN   NaN
# ...                   ...                 ...   ...    ...   ...   ...   ...
# 103954            2200.00 2025-09-17 12:00:00 25.90   7.80 16.85   NaN   NaN
# 103955            2200.00 2025-09-18 12:00:00 25.40   4.70 15.05   NaN   NaN
# 103956            2200.00 2025-09-19 12:00:00 27.50   7.20 17.35   NaN   NaN
# 103957            2200.00 2025-09-20 12:00:00 22.00   7.00 14.50   NaN   NaN
# 103958            2200.00 2025-09-21 12:00:00 22.10   2.60 12.35   NaN   NaN
#
#         um  ffm  sshn  rrr24  FAO56  Hargreaves
# 95679  NaN  NaN   NaN    NaN    NaN        1.21
# 95680  NaN  NaN   NaN    NaN    NaN        1.16
# 95681  NaN  NaN   NaN    NaN    NaN        1.22
# 95682  NaN  NaN   NaN    NaN    NaN        1.01
# 95683  NaN  NaN   NaN   1.50    NaN        1.43
# ...     ..  ...   ...    ...    ...         ...
# 103954 NaN  NaN   NaN   0.00    NaN        4.27
# 103955 NaN  NaN   NaN   0.00    NaN        4.29
# 103956 NaN  NaN   NaN   0.10    NaN        4.52
# 103957 NaN  NaN   NaN    NaN    NaN        3.53
# 103958 NaN  NaN   NaN   0.00    NaN        3.72
#
# [8280 rows x 19 columns]
# Reindexing station 18622
#       station_id                   station_name region_id region_name   lat  \
# 94714      18622  Shahrak Sanati Daroii Barakat      ALKK      Alborz 35.92
# 94715      18622  Shahrak Sanati Daroii Barakat      ALKK      Alborz 35.92
# 94716      18622  Shahrak Sanati Daroii Barakat      ALKK      Alborz 35.92
# 94717      18622  Shahrak Sanati Daroii Barakat      ALKK      Alborz 35.92
# 94718      18622  Shahrak Sanati Daroii Barakat      ALKK      Alborz 35.92
# ...          ...                            ...       ...         ...   ...
# 95674      18622  Shahrak Sanati Daroii Barakat      ALKK      Alborz 35.92
# 95675      18622  Shahrak Sanati Daroii Barakat      ALKK      Alborz 35.92
# 95676      18622  Shahrak Sanati Daroii Barakat      ALKK      Alborz 35.92
# 95677      18622  Shahrak Sanati Daroii Barakat      ALKK      Alborz 35.92
# 95678      18622  Shahrak Sanati Daroii Barakat      ALKK      Alborz 35.92
#
#         lon  station_elevation                date  tmax  tmin    tm  umax  \
# 94714 50.86            1455.00 2023-01-01 12:00:00  5.40 -0.50  2.45   NaN
# 94715 50.86            1455.00 2023-01-02 12:00:00  6.80 -0.30  3.25   NaN
# 94716 50.86            1455.00 2023-01-03 12:00:00  8.40 -0.90  3.75   NaN
# 94717 50.86            1455.00 2023-01-04 12:00:00  6.70  0.60  3.65   NaN
# 94718 50.86            1455.00 2023-01-05 12:00:00  3.90 -0.40  1.75   NaN
# ...     ...                ...                 ...   ...   ...   ...   ...
# 95674 50.86            1455.00 2025-09-17 12:00:00 29.80 19.60 24.70   NaN
# 95675 50.86            1455.00 2025-09-18 12:00:00 30.20 13.30 21.75   NaN
# 95676 50.86            1455.00 2025-09-19 12:00:00 32.50 23.20 27.85   NaN
# 95677 50.86            1455.00 2025-09-20 12:00:00 29.20 20.10 24.65   NaN
# 95678 50.86            1455.00 2025-09-21 12:00:00 26.90  9.70 18.30   NaN
#
#        umin  um  ffm  sshn  rrr24  FAO56  Hargreaves
# 94714   NaN NaN  NaN   NaN   0.00    NaN        0.74
# 94715   NaN NaN  NaN   NaN   0.00    NaN        0.85
# 94716   NaN NaN  NaN   NaN   0.00    NaN        1.00
# 94717   NaN NaN  NaN   NaN   0.00    NaN        0.81
# 94718   NaN NaN  NaN   NaN   1.80    NaN        0.62
# ...     ...  ..  ...   ...    ...    ...         ...
# 95674   NaN NaN  NaN   NaN   0.00    NaN        3.96
# 95675   NaN NaN  NaN   NaN   0.00    NaN        4.70
# 95676   NaN NaN  NaN   NaN   0.00    NaN        4.02
# 95677   NaN NaN  NaN   NaN   0.00    NaN        3.65
# 95678   NaN NaN  NaN   NaN   0.00    NaN        4.22
#
# [965 rows x 19 columns]
# Reindexing station 18632
#       station_id station_name region_id region_name   lat   lon  \
# 93248      18632   Piste Khur      ALKK      Alborz 35.91 51.16
# 93249      18632   Piste Khur      ALKK      Alborz 35.91 51.16
# 93250      18632   Piste Khur      ALKK      Alborz 35.91 51.16
# 93251      18632   Piste Khur      ALKK      Alborz 35.91 51.16
# 93252      18632   Piste Khur      ALKK      Alborz 35.91 51.16
# ...          ...          ...       ...         ...   ...   ...
# 93763      18632   Piste Khur      ALKK      Alborz 35.91 51.16
# 93764      18632   Piste Khur      ALKK      Alborz 35.91 51.16
# 93765      18632   Piste Khur      ALKK      Alborz 35.91 51.16
# 93766      18632   Piste Khur      ALKK      Alborz 35.91 51.16
# 93767      18632   Piste Khur      ALKK      Alborz 35.91 51.16
#
#        station_elevation                date  tmax  tmin    tm  umax  umin  \
# 93248            2415.00 2024-03-30 12:00:00 11.00  0.60  5.80   NaN   NaN
# 93249            2415.00 2024-03-31 12:00:00 10.50  3.70  7.10   NaN   NaN
# 93250            2415.00 2024-04-01 12:00:00 11.40  1.50  6.45   NaN   NaN
# 93251            2415.00 2024-04-02 12:00:00 10.60  0.00  5.30   NaN   NaN
# 93252            2415.00 2024-04-03 12:00:00 11.70  1.30  6.50   NaN   NaN
# ...                  ...                 ...   ...   ...   ...   ...   ...
# 93763            2415.00 2025-09-17 12:00:00 22.10 13.70 17.90   NaN   NaN
# 93764            2415.00 2025-09-18 12:00:00 22.90 13.10 18.00   NaN   NaN
# 93765            2415.00 2025-09-19 12:00:00 25.10 14.90 20.00   NaN   NaN
# 93766            2415.00 2025-09-20 12:00:00 21.00 12.10 16.55   NaN   NaN
# 93767            2415.00 2025-09-21 12:00:00 19.20  9.80 14.50   NaN   NaN
#
#        um  ffm  sshn  rrr24  FAO56  Hargreaves
# 93248 NaN  NaN   NaN   0.00    NaN        2.30
# 93249 NaN  NaN   NaN   0.00    NaN        1.98
# 93250 NaN  NaN   NaN   0.00    NaN        2.34
# 93251 NaN  NaN   NaN   0.00    NaN        2.32
# 93252 NaN  NaN   NaN   0.00    NaN        2.43
# ...    ..  ...   ...    ...    ...         ...
# 93763 NaN  NaN   NaN   0.00    NaN        3.00
# 93764 NaN  NaN   NaN   0.00    NaN        3.23
# 93765 NaN  NaN   NaN   0.00    NaN        3.46
# 93766 NaN  NaN   NaN   0.00    NaN        2.90
# 93767 NaN  NaN   NaN   0.00    NaN        2.78
#
# [520 rows x 19 columns]
# Reindexing station 18703
#       station_id   station_name region_id region_name   lat   lon  \
# 87854      18703  Meshkin Dasht      ALKK      Alborz 35.76 50.96
# 87855      18703  Meshkin Dasht      ALKK      Alborz 35.76 50.96
# 87856      18703  Meshkin Dasht      ALKK      Alborz 35.76 50.96
# 87857      18703  Meshkin Dasht      ALKK      Alborz 35.76 50.96
# 87858      18703  Meshkin Dasht      ALKK      Alborz 35.76 50.96
# ...          ...            ...       ...         ...   ...   ...
# 88812      18703  Meshkin Dasht      ALKK      Alborz 35.76 50.96
# 88813      18703  Meshkin Dasht      ALKK      Alborz 35.76 50.96
# 88814      18703  Meshkin Dasht      ALKK      Alborz 35.76 50.96
# 88815      18703  Meshkin Dasht      ALKK      Alborz 35.76 50.96
# 88816      18703  Meshkin Dasht      ALKK      Alborz 35.76 50.96
#
#        station_elevation                date  tmax  tmin    tm  umax  umin  \
# 87854            1289.00 2023-01-01 12:00:00  7.20 -2.60  2.30   NaN   NaN
# 87855            1289.00 2023-01-02 12:00:00  8.30 -2.60  2.85   NaN   NaN
# 87856            1289.00 2023-01-03 12:00:00 10.30 -3.40  3.45   NaN   NaN
# 87857            1289.00 2023-01-04 12:00:00  8.40 -1.60  3.40   NaN   NaN
# 87858            1289.00 2023-01-05 12:00:00  5.10  0.40  2.75   NaN   NaN
# ...                  ...                 ...   ...   ...   ...   ...   ...
# 88812            1289.00 2025-09-17 12:00:00 32.50 14.10 23.30   NaN   NaN
# 88813            1289.00 2025-09-18 12:00:00 31.80 13.50 22.65   NaN   NaN
# 88814            1289.00 2025-09-19 12:00:00 33.80 20.20 27.00   NaN   NaN
# 88815            1289.00 2025-09-20 12:00:00 30.40 16.70 23.55   NaN   NaN
# 88816            1289.00 2025-09-21 12:00:00 29.10  9.90 19.50   NaN   NaN
#
#        um  ffm  sshn  rrr24  FAO56  Hargreaves
# 87854 NaN  NaN   NaN   0.00    NaN        0.95
# 87855 NaN  NaN   NaN   0.00    NaN        1.04
# 87856 NaN  NaN   NaN   0.00    NaN        1.20
# 87857 NaN  NaN   NaN   0.00    NaN        1.03
# 87858 NaN  NaN   NaN   0.40    NaN        0.69
# ...    ..  ...   ...    ...    ...         ...
# 88812 NaN  NaN   NaN   0.00    NaN        5.15
# 88813 NaN  NaN   NaN   0.00    NaN        5.01
# 88814 NaN  NaN   NaN   0.00    NaN        4.77
# 88815 NaN  NaN   NaN   0.00    NaN        4.37
# 88816 NaN  NaN   NaN   0.00    NaN        4.62
#
# [963 rows x 19 columns]
# Reindexing station 18712
#       station_id station_name region_id region_name   lat   lon  \
# 59974      18712    Eshtehard      ALKK      Alborz 35.72 50.37
# 59975      18712    Eshtehard      ALKK      Alborz 35.72 50.37
# 59976      18712    Eshtehard      ALKK      Alborz 35.72 50.37
# 59977      18712    Eshtehard      ALKK      Alborz 35.72 50.37
# 59978      18712    Eshtehard      ALKK      Alborz 35.72 50.37
# ...          ...          ...       ...         ...   ...   ...
# 60926      18712    Eshtehard      ALKK      Alborz 35.72 50.37
# 60927      18712    Eshtehard      ALKK      Alborz 35.72 50.37
# 60928      18712    Eshtehard      ALKK      Alborz 35.72 50.37
# 60929      18712    Eshtehard      ALKK      Alborz 35.72 50.37
# 60930      18712    Eshtehard      ALKK      Alborz 35.72 50.37
#
#        station_elevation                date  tmax  tmin    tm  umax  umin  \
# 59974            1191.00 2023-01-01 12:00:00  9.30 -6.20  1.55   NaN   NaN
# 59975            1191.00 2023-01-02 12:00:00  9.40 -6.10  1.65   NaN   NaN
# 59976            1191.00 2023-01-03 12:00:00  8.90 -6.90  1.00   NaN   NaN
# 59977            1191.00 2023-01-04 12:00:00  8.90 -7.00  0.95   NaN   NaN
# 59978            1191.00 2023-01-05 12:00:00  5.20  0.00  2.60   NaN   NaN
# ...                  ...                 ...   ...   ...   ...   ...   ...
# 60926            1191.00 2025-09-17 12:00:00 33.60 15.10 24.35   NaN   NaN
# 60927            1191.00 2025-09-18 12:00:00 33.70 15.90 24.80   NaN   NaN
# 60928            1191.00 2025-09-19 12:00:00 37.60 24.80 31.20   NaN   NaN
# 60929            1191.00 2025-09-20 12:00:00 32.90 18.10 25.50   NaN   NaN
# 60930            1191.00 2025-09-21 12:00:00 29.60 13.60 21.60   NaN   NaN
#
#        um  ffm  sshn  rrr24  FAO56  Hargreaves
# 59974 NaN  NaN   NaN   0.00    NaN        1.16
# 59975 NaN  NaN   NaN   0.00    NaN        1.17
# 59976 NaN  NaN   NaN   0.00    NaN        1.14
# 59977 NaN  NaN   NaN   0.00    NaN        1.15
# 59978 NaN  NaN   NaN   0.30    NaN        0.72
# ...    ..  ...   ...    ...    ...         ...
# 60926 NaN  NaN   NaN   0.00    NaN        5.30
# 60927 NaN  NaN   NaN   0.00    NaN        5.22
# 60928 NaN  NaN   NaN   0.00    NaN        5.09
# 60929 NaN  NaN   NaN   0.00    NaN        4.77
# 60930 NaN  NaN   NaN   0.00    NaN        4.46
#
# [957 rows x 19 columns]
# Reindexing station 40752
#       station_id station_name region_id region_name   lat   lon  \
# 68301      40752        Karaj      ALKK      Alborz 35.81 50.95
# 68302      40752        Karaj      ALKK      Alborz 35.81 50.95
# 68303      40752        Karaj      ALKK      Alborz 35.81 50.95
# 68304      40752        Karaj      ALKK      Alborz 35.81 50.95
# 68305      40752        Karaj      ALKK      Alborz 35.81 50.95
# ...          ...          ...       ...         ...   ...   ...
# 83170      40752        Karaj      ALKK      Alborz 35.81 50.95
# 83171      40752        Karaj      ALKK      Alborz 35.81 50.95
# 83172      40752        Karaj      ALKK      Alborz 35.81 50.95
# 83173      40752        Karaj      ALKK      Alborz 35.81 50.95
# 83174      40752        Karaj      ALKK      Alborz 35.81 50.95
#
#        station_elevation                date  tmax   tmin    tm  umax  umin  \
# 68301            1292.90 1985-01-01 12:00:00  1.60 -12.00 -3.70 84.00 71.00
# 68302            1292.90 1985-01-02 12:00:00 -1.00    NaN -2.00 94.00 93.00
# 68303            1292.90 1985-01-03 12:00:00  1.40  -9.00 -4.40 96.00 69.00
# 68304            1292.90 1985-01-04 12:00:00  2.20 -14.00 -2.30 69.00 52.00
# 68305            1292.90 1985-01-05 12:00:00  1.40 -10.00 -3.50 76.00 48.00
# ...                  ...                 ...   ...    ...   ...   ...   ...
# 83170            1292.90 2025-09-17 12:00:00 31.40  14.10 22.80 76.00 13.00
# 83171            1292.90 2025-09-18 12:00:00 30.80  15.40 23.10 74.00 14.00
# 83172            1292.90 2025-09-19 12:00:00 33.50  22.30 27.90 33.00 11.00
# 83173            1292.90 2025-09-20 12:00:00 28.10  16.30 22.20 70.00 13.00
# 83174            1292.90 2025-09-21 12:00:00 28.00  11.90 20.00 76.00 15.00
#
#          um  ffm  sshn  rrr24  FAO56  Hargreaves
# 68301 79.20 0.40  1.40   0.00   0.45        0.78
# 68302 93.60 2.40  0.00   7.50    NaN         NaN
# 68303 84.60 1.20  5.60   2.00   0.49        0.65
# 68304 62.40 1.20  7.40   0.00   0.72        0.95
# 68305 62.40 0.00  5.60   0.00   0.46        0.74
# ...     ...  ...   ...    ...    ...         ...
# 83170 43.25 2.29 10.40   0.00   4.78        4.92
# 83171 35.83 2.33 10.60   0.00   4.88        4.65
# 83172 17.17 3.79 10.20   0.00   7.82        4.42
# 83173 28.25 4.38  8.10   0.00   5.50        3.92
# 83174 46.64 3.27  9.80   0.00   4.60        4.28
#
# [14874 rows x 19 columns]
# Reindexing station 75201
#       station_id      station_name region_id region_name   lat   lon  \
# 68117      75201  Kandoovan Jonobi      ALKK      Alborz 36.13 51.32
# 68118      75201  Kandoovan Jonobi      ALKK      Alborz 36.13 51.32
# 68119      75201  Kandoovan Jonobi      ALKK      Alborz 36.13 51.32
# 68120      75201  Kandoovan Jonobi      ALKK      Alborz 36.13 51.32
# 68121      75201  Kandoovan Jonobi      ALKK      Alborz 36.13 51.32
# ...          ...               ...       ...         ...   ...   ...
# 68296      75201  Kandoovan Jonobi      ALKK      Alborz 36.13 51.32
# 68297      75201  Kandoovan Jonobi      ALKK      Alborz 36.13 51.32
# 68298      75201  Kandoovan Jonobi      ALKK      Alborz 36.13 51.32
# 68299      75201  Kandoovan Jonobi      ALKK      Alborz 36.13 51.32
# 68300      75201  Kandoovan Jonobi      ALKK      Alborz 36.13 51.32
#
#        station_elevation                date  tmax  tmin    tm   umax  umin  \
# 68117            2583.00 2024-05-29 12:00:00 20.00 15.30 17.60  44.00 27.00
# 68118            2583.00 2024-05-30 12:00:00 26.00 10.10 18.00  56.00 17.00
# 68119            2583.00 2024-05-31 12:00:00 27.20 11.60 19.40  54.00 14.00
# 68120            2583.00 2024-06-01 12:00:00 27.10 13.30 20.20  32.00 16.00
# 68121            2583.00 2024-06-02 12:00:00 13.00  5.60  9.30 100.00 67.00
# ...                  ...                 ...   ...   ...   ...    ...   ...
# 68296            2583.00 2025-01-24 12:00:00   NaN   NaN   NaN  39.00 39.00
# 68297            2583.00 2025-01-29 12:00:00  1.00 -9.00 -4.00  48.00 27.00
# 68298            2583.00 2025-01-30 12:00:00  0.10 -7.60 -3.80  35.00 21.00
# 68299            2583.00 2025-01-31 12:00:00  4.60 -7.40 -1.40  55.00 23.00
# 68300            2583.00 2025-02-01 12:00:00   NaN -8.50   NaN  47.00 27.00
#
#          um  ffm  sshn  rrr24  FAO56  Hargreaves
# 68117 34.00 0.71   NaN    NaN    NaN        2.95
# 68118 36.50 0.17   NaN    NaN    NaN        5.50
# 68119 32.75 0.00   NaN    NaN    NaN        5.68
# 68120 22.25 0.21   NaN    NaN    NaN        5.46
# 68121 95.62 1.27   NaN    NaN    NaN        2.83
# ...     ...  ...   ...    ...    ...         ...
# 68296 39.00 0.00   NaN    NaN    NaN         NaN
# 68297 38.50 0.00   NaN    NaN    NaN        0.77
# 68298 26.50 0.00   NaN    NaN    NaN        0.69
# 68299 36.00 0.00   NaN    NaN    NaN        1.03
# 68300 36.00 0.00   NaN    NaN    NaN         NaN
#
# [184 rows x 19 columns]
# Reindexing station 88125
#       station_id   station_name region_id region_name   lat   lon  \
# 90493      88125  Payam Airport      ALKK      Alborz 35.77 50.84
# 90494      88125  Payam Airport      ALKK      Alborz 35.77 50.84
# 90495      88125  Payam Airport      ALKK      Alborz 35.77 50.84
# 90496      88125  Payam Airport      ALKK      Alborz 35.77 50.84
# 90497      88125  Payam Airport      ALKK      Alborz 35.77 50.84
# ...          ...            ...       ...         ...   ...   ...
# 93243      88125  Payam Airport      ALKK      Alborz 35.77 50.84
# 93244      88125  Payam Airport      ALKK      Alborz 35.77 50.84
# 93245      88125  Payam Airport      ALKK      Alborz 35.77 50.84
# 93246      88125  Payam Airport      ALKK      Alborz 35.77 50.84
# 93247      88125  Payam Airport      ALKK      Alborz 35.77 50.84
#
#        station_elevation                date  tmax  tmin    tm  umax  umin  \
# 90493            1259.80 2012-01-01 12:00:00  4.40   NaN  3.00   NaN   NaN
# 90494            1259.80 2012-01-02 12:00:00   NaN  1.00  2.10   NaN   NaN
# 90495            1259.80 2012-01-03 12:00:00  7.00   NaN  3.30   NaN   NaN
# 90496            1259.80 2012-01-04 12:00:00  4.40   NaN  0.80   NaN   NaN
# 90497            1259.80 2012-01-05 12:00:00  6.40 -4.60  0.70   NaN   NaN
# ...                  ...                 ...   ...   ...   ...   ...   ...
# 93243            1259.80 2025-09-17 12:00:00 30.80 15.10 23.00 68.00 15.00
# 93244            1259.80 2025-09-18 12:00:00 30.80 14.30 22.50 80.00 18.00
# 93245            1259.80 2025-09-19 12:00:00 33.10 21.80 27.40 28.00 12.00
# 93246            1259.80 2025-09-20 12:00:00 27.50 19.40 23.50 63.00 15.00
# 93247            1259.80 2025-09-21 12:00:00 27.40 11.40 19.40 71.00 15.00
#
#          um  ffm  sshn  rrr24  FAO56  Hargreaves
# 90493   NaN 1.00  0.00   6.00    NaN         NaN
# 90494   NaN 0.00   NaN   2.00    NaN         NaN
# 90495   NaN 3.50  6.70   0.00    NaN         NaN
# 90496   NaN 6.20  9.00   0.00    NaN         NaN
# 90497   NaN 2.00   NaN    NaN    NaN        0.94
# ...     ...  ...   ...    ...    ...         ...
# 93243 43.75 4.50 10.60   0.00   6.08        4.72
# 93244 39.62 3.50 10.80   0.00   5.07        4.74
# 93245 17.50 5.25 10.50   0.00   9.33        4.39
# 93246 26.62 7.88  8.10   0.00   7.54        3.36
# 93247 46.50 6.88 10.20   0.00   5.85        4.20
#
# [2755 rows x 19 columns]
# Reindexing station 90220
#       station_id station_name region_id region_name   lat   lon  \
# 88817      90220    Nazarabad      ALKK      Alborz 35.93 50.55
# 88818      90220    Nazarabad      ALKK      Alborz 35.93 50.55
# 88819      90220    Nazarabad      ALKK      Alborz 35.93 50.55
# 88820      90220    Nazarabad      ALKK      Alborz 35.93 50.55
# 88821      90220    Nazarabad      ALKK      Alborz 35.93 50.55
# ...          ...          ...       ...         ...   ...   ...
# 90488      90220    Nazarabad      ALKK      Alborz 35.93 50.55
# 90489      90220    Nazarabad      ALKK      Alborz 35.93 50.55
# 90490      90220    Nazarabad      ALKK      Alborz 35.93 50.55
# 90491      90220    Nazarabad      ALKK      Alborz 35.93 50.55
# 90492      90220    Nazarabad      ALKK      Alborz 35.93 50.55
#
#        station_elevation                date  tmax  tmin    tm  umax  umin  \
# 88817            1168.00 2021-01-29 12:00:00 17.40  5.90  9.90 85.00 23.00
# 88818            1168.00 2021-01-30 12:00:00 13.60  4.10  6.90 94.00 42.00
# 88819            1168.00 2021-01-31 12:00:00  9.70 -3.30  2.90 82.00 32.00
# 88820            1168.00 2021-02-01 12:00:00 15.20 -2.60  4.30 87.00 35.00
# 88821            1168.00 2021-02-02 12:00:00 16.60 -4.60  3.80 94.00 30.00
# ...                  ...                 ...   ...   ...   ...   ...   ...
# 90488            1168.00 2025-09-17 12:00:00 33.10 12.40 22.80 76.00 17.00
# 90489            1168.00 2025-09-18 12:00:00 33.20 12.60 22.90 84.00 17.00
# 90490            1168.00 2025-09-19 12:00:00 34.80 19.80 27.30 34.00  9.00
# 90491            1168.00 2025-09-20 12:00:00 26.70 16.20 21.50 62.00 21.00
# 90492            1168.00 2025-09-21 12:00:00 30.20  9.90 20.00 78.00 13.00
#
#          um  ffm  sshn  rrr24  FAO56  Hargreaves
# 88817 40.88 3.75   NaN   0.00    NaN        1.70
# 88818 66.12 2.50   NaN   6.30    NaN        1.38
# 88819 59.62 2.62   NaN   0.00    NaN        1.36
# 88820 66.62 1.75   NaN   0.00    NaN        1.72
# 88821 68.38 0.75   NaN   0.00    NaN        1.85
# ...     ...  ...   ...    ...    ...         ...
# 90488 48.50 1.05   NaN   0.00    NaN        5.38
# 90489 42.00 0.72   NaN   0.00    NaN        5.34
# 90490 21.62 2.00   NaN   0.00    NaN        5.03
# 90491 34.80 0.92   NaN   0.00    NaN        3.62
# 90492 49.75 1.38   NaN   0.00    NaN        4.80
#
# [1676 rows x 19 columns]
# Reindexing station 99321
#        station_id station_name region_id region_name   lat   lon  \
# 103959      99321     Taleghan      ALKK      Alborz 36.18 50.77
# 103960      99321     Taleghan      ALKK      Alborz 36.18 50.77
# 103961      99321     Taleghan      ALKK      Alborz 36.18 50.77
# 103962      99321     Taleghan      ALKK      Alborz 36.18 50.77
# 103963      99321     Taleghan      ALKK      Alborz 36.18 50.77
# ...           ...          ...       ...         ...   ...   ...
# 110427      99321     Taleghan      ALKK      Alborz 36.18 50.77
# 110428      99321     Taleghan      ALKK      Alborz 36.18 50.77
# 110429      99321     Taleghan      ALKK      Alborz 36.18 50.77
# 110430      99321     Taleghan      ALKK      Alborz 36.18 50.77
# 110431      99321     Taleghan      ALKK      Alborz 36.18 50.77
#
#         station_elevation                date  tmax   tmin    tm  umax  umin  \
# 103959            1857.00 2008-01-01 12:00:00  4.40  -4.00  0.20 96.00 63.00
# 103960            1857.00 2008-01-02 12:00:00  2.00  -2.80 -0.30 98.00 86.00
# 103961            1857.00 2008-01-03 12:00:00  1.00  -3.20 -1.60 93.00 82.00
# 103962            1857.00 2008-01-04 12:00:00  1.20 -10.60 -3.90 86.00 72.00
# 103963            1857.00 2008-01-05 12:00:00  2.20  -7.40 -3.30 79.00 49.00
# ...                   ...                 ...   ...    ...   ...   ...   ...
# 110427            1857.00 2025-09-17 12:00:00 26.80  10.90 18.80 78.00 16.00
# 110428            1857.00 2025-09-18 12:00:00 27.60   8.60 18.10 85.00 13.00
# 110429            1857.00 2025-09-19 12:00:00 29.40  15.20 22.30 30.00 14.00
# 110430            1857.00 2025-09-20 12:00:00 23.70  11.50 17.60 44.00 18.00
# 110431            1857.00 2025-09-21 12:00:00 23.60   6.90 15.30 78.00 13.00
#
#           um  ffm  sshn  rrr24  FAO56  Hargreaves
# 103959 77.40 0.00  5.50   3.00   0.56        0.78
# 103960 94.00 0.00  0.00   8.00   0.48        0.57
# 103961 87.20 0.60  0.10   8.00   0.48        0.50
# 103962 78.40 0.00  4.20   1.00   0.47        0.72
# 103963 65.40 0.60  2.50   0.00   0.58        0.68
# ...      ...  ...   ...    ...    ...         ...
# 110427 48.46 1.88 10.50   0.00   4.08        4.22
# 110428 34.62 2.21 10.70   0.00   3.99        4.49
# 110429 20.21 2.79 10.50   0.00   6.02        4.32
# 110430 27.44 3.00   NaN   0.00    NaN        3.49
# 110431 42.29 2.48 10.50   0.00   3.78        3.78
#
# [6473 rows x 19 columns]
# Reindexing station 99373
#       station_id          station_name region_id region_name   lat   lon  \
# 83175      99373  Karaj (Agricultural)      ALKK      Alborz 35.78 50.94
# 83176      99373  Karaj (Agricultural)      ALKK      Alborz 35.78 50.94
# 83177      99373  Karaj (Agricultural)      ALKK      Alborz 35.78 50.94
# 83178      99373  Karaj (Agricultural)      ALKK      Alborz 35.78 50.94
# 83179      99373  Karaj (Agricultural)      ALKK      Alborz 35.78 50.94
# ...          ...                   ...       ...         ...   ...   ...
# 87849      99373  Karaj (Agricultural)      ALKK      Alborz 35.78 50.94
# 87850      99373  Karaj (Agricultural)      ALKK      Alborz 35.78 50.94
# 87851      99373  Karaj (Agricultural)      ALKK      Alborz 35.78 50.94
# 87852      99373  Karaj (Agricultural)      ALKK      Alborz 35.78 50.94
# 87853      99373  Karaj (Agricultural)      ALKK      Alborz 35.78 50.94
#
#        station_elevation                date  tmax  tmin    tm  umax  umin  \
# 83175            1261.10 2004-01-01 12:00:00  6.20 -5.80  1.00   NaN   NaN
# 83176            1261.10 2004-01-02 12:00:00  2.80 -5.20  1.00   NaN   NaN
# 83177            1261.10 2004-01-03 12:00:00  0.80 -0.20  0.20   NaN   NaN
# 83178            1261.10 2004-01-04 12:00:00  2.00 -3.00 -1.20   NaN   NaN
# 83179            1261.10 2004-01-05 12:00:00  6.60 -4.60  2.00   NaN   NaN
# ...                  ...                 ...   ...   ...   ...   ...   ...
# 87849            1261.10 2025-09-17 12:00:00 34.00 14.00 24.00 79.00 13.00
# 87850            1261.10 2025-09-18 12:00:00 32.20 14.20 23.20 84.00 17.00
# 87851            1261.10 2025-09-19 12:00:00 34.50 18.20 26.40 37.00 12.00
# 87852            1261.10 2025-09-20 12:00:00 29.60 15.40 22.50 64.00 15.00
# 87853            1261.10 2025-09-21 12:00:00 30.30 10.60 20.50 86.00 13.00
#
#          um  ffm  sshn  rrr24  FAO56  Hargreaves
# 83175   NaN 0.40  7.30   0.00    NaN        0.99
# 83176   NaN 0.00  0.10   6.00    NaN        0.81
# 83177   NaN 1.20  0.00   6.01    NaN        0.27
# 83178   NaN 1.80  5.60   3.00    NaN        0.57
# 83179   NaN 0.00  2.90   0.00    NaN        1.02
# ...     ...  ...   ...    ...    ...         ...
# 87849 46.50 1.29   NaN   0.00    NaN        5.46
# 87850 39.67 1.36   NaN   0.00    NaN        5.04
# 87851 19.88 2.24   NaN   0.00    NaN        5.15
# 87852 30.38 2.54   NaN   0.00    NaN        4.33
# 87853 51.62 2.59   NaN   0.00    NaN        4.81
#
# [4679 rows x 19 columns]
# Reindexing station 99396
#       station_id station_name region_id region_name   lat   lon  \
# 60931      99396    Hashtgerd      ALKK      Alborz 36.01 50.75
# 60932      99396    Hashtgerd      ALKK      Alborz 36.01 50.75
# 60933      99396    Hashtgerd      ALKK      Alborz 36.01 50.75
# 60934      99396    Hashtgerd      ALKK      Alborz 36.01 50.75
# 60935      99396    Hashtgerd      ALKK      Alborz 36.01 50.75
# ...          ...          ...       ...         ...   ...   ...
# 68112      99396    Hashtgerd      ALKK      Alborz 36.01 50.75
# 68113      99396    Hashtgerd      ALKK      Alborz 36.01 50.75
# 68114      99396    Hashtgerd      ALKK      Alborz 36.01 50.75
# 68115      99396    Hashtgerd      ALKK      Alborz 36.01 50.75
# 68116      99396    Hashtgerd      ALKK      Alborz 36.01 50.75
#
#        station_elevation                date  tmax  tmin    tm   umax  umin  \
# 60931            1612.90 2006-01-01 12:00:00  2.60 -5.00 -0.60  82.00 37.00
# 60932            1612.90 2006-01-02 12:00:00  2.00 -4.40 -1.20  59.00 45.00
# 60933            1612.90 2006-01-03 12:00:00  2.80 -4.00 -0.70  63.00 53.00
# 60934            1612.90 2006-01-04 12:00:00  4.40 -3.60  0.40  60.00 43.00
# 60935            1612.90 2006-01-05 12:00:00  4.80 -3.40  0.70  61.00 55.00
# ...                  ...                 ...   ...   ...   ...    ...   ...
# 68112            1612.90 2025-09-17 12:00:00 28.70 17.60 23.20  79.00 14.00
# 68113            1612.90 2025-09-18 12:00:00 28.70 12.20 20.50  87.00 15.00
# 68114            1612.90 2025-09-19 12:00:00 31.00 19.30 25.10  23.00 11.00
# 68115            1612.90 2025-09-20 12:00:00 24.70 18.80 21.80  66.00 12.00
# 68116            1612.90 2025-09-21 12:00:00   NaN  8.80   NaN 100.00 32.00
#
#          um  ffm  sshn  rrr24  FAO56  Hargreaves
# 60931 52.40 0.00  8.80   0.00   0.52        0.71
# 60932 50.20 0.60  2.00   0.00   0.68        0.63
# 60933 58.80 0.60  5.60   0.00   0.69        0.67
# 60934 53.40 0.00  8.50   0.00   0.52        0.78
# 60935 58.20 0.60  8.50   0.00   0.76        0.81
# ...     ...  ...   ...    ...    ...         ...
# 68112 39.50 2.04   NaN   0.00    NaN        3.98
# 68113 34.88 2.04   NaN   0.00    NaN        4.48
# 68114 16.47 3.68   NaN   0.00    NaN        4.22
# 68115 25.13 4.35   NaN   0.00    NaN        2.73
# 68116 67.23 1.46   NaN   0.00    NaN         NaN
#
# [7186 rows x 19 columns]
# Reindexing station 18915
#         station_id station_name region_id region_name   lat   lon  \
# 3461435      18915         Aveh      MAAA     Markazi 34.80 50.38
# 3461436      18915         Aveh      MAAA     Markazi 34.80 50.38
# 3461437      18915         Aveh      MAAA     Markazi 34.80 50.38
# 3461438      18915         Aveh      MAAA     Markazi 34.80 50.38
# 3461439      18915         Aveh      MAAA     Markazi 34.80 50.38
# 3461440      18915         Aveh      MAAA     Markazi 34.80 50.38
# 3461441      18915         Aveh      MAAA     Markazi 34.80 50.38
# 3461442      18915         Aveh      MAAA     Markazi 34.80 50.38
#
#          station_elevation                date  tmax  tmin    tm  umax  umin  \
# 3461435            1000.00 2025-09-14 12:00:00 33.30 19.60 26.45   NaN   NaN
# 3461436            1000.00 2025-09-15 12:00:00 33.20 20.30 26.75   NaN   NaN
# 3461437            1000.00 2025-09-16 12:00:00 33.60 18.10 25.85   NaN   NaN
# 3461438            1000.00 2025-09-17 12:00:00 36.50 17.40 26.95   NaN   NaN
# 3461439            1000.00 2025-09-18 12:00:00 34.70 18.30 26.50   NaN   NaN
# 3461440            1000.00 2025-09-19 12:00:00 38.20 17.60 27.90   NaN   NaN
# 3461441            1000.00 2025-09-20 12:00:00 34.50 19.70 27.10   NaN   NaN
# 3461442            1000.00 2025-09-21 12:00:00 32.30 13.60 22.95   NaN   NaN
#
#          um  ffm  sshn  rrr24  FAO56  Hargreaves
# 3461435 NaN  NaN   NaN    NaN    NaN        4.95
# 3461436 NaN  NaN   NaN   0.00    NaN        4.80
# 3461437 NaN  NaN   NaN   0.00    NaN        5.12
# 3461438 NaN  NaN   NaN   0.00    NaN        5.79
# 3461439 NaN  NaN   NaN   0.00    NaN        5.27
# 3461440 NaN  NaN   NaN   0.00    NaN        6.06
# 3461441 NaN  NaN   NaN   0.00    NaN        5.01
# 3461442 NaN  NaN   NaN   0.00    NaN        5.05
# Reindexing station 18975
#         station_id station_name region_id region_name   lat   lon  \
# 3535746      18975   Varin Bala      MAAA     Markazi 34.03 50.37
# 3535747      18975   Varin Bala      MAAA     Markazi 34.03 50.37
# 3535748      18975   Varin Bala      MAAA     Markazi 34.03 50.37
# 3535749      18975   Varin Bala      MAAA     Markazi 34.03 50.37
# 3535750      18975   Varin Bala      MAAA     Markazi 34.03 50.37
# 3535751      18975   Varin Bala      MAAA     Markazi 34.03 50.37
# 3535752      18975   Varin Bala      MAAA     Markazi 34.03 50.37
# 3535753      18975   Varin Bala      MAAA     Markazi 34.03 50.37
#
#          station_elevation                date  tmax  tmin    tm  umax  umin  \
# 3535746            1808.00 2025-09-14 12:00:00 28.20 15.40 21.80   NaN   NaN
# 3535747            1808.00 2025-09-15 12:00:00 26.70 13.80 20.25   NaN   NaN
# 3535748            1808.00 2025-09-16 12:00:00 27.70 14.10 20.90   NaN   NaN
# 3535749            1808.00 2025-09-17 12:00:00 29.60 14.90 22.25   NaN   NaN
# 3535750            1808.00 2025-09-18 12:00:00 30.60 15.50 23.05   NaN   NaN
# 3535751            1808.00 2025-09-19 12:00:00 32.40 18.80 25.60   NaN   NaN
# 3535752            1808.00 2025-09-20 12:00:00 29.50 16.80 23.15   NaN   NaN
# 3535753            1808.00 2025-09-21 12:00:00 28.30 12.90 20.60   NaN   NaN
#
#          um  ffm  sshn  rrr24  FAO56  Hargreaves
# 3535746 NaN  NaN   NaN    NaN    NaN        4.29
# 3535747 NaN  NaN   NaN   0.00    NaN        4.11
# 3535748 NaN  NaN   NaN   0.00    NaN        4.27
# 3535749 NaN  NaN   NaN   0.00    NaN        4.57
# 3535750 NaN  NaN   NaN   0.00    NaN        4.69
# 3535751 NaN  NaN   NaN   0.00    NaN        4.71
# 3535752 NaN  NaN   NaN   0.00    NaN        4.26
# 3535753 NaN  NaN   NaN   0.00    NaN        4.35
# Reindexing station 19060
#         station_id station_name region_id region_name   lat   lon  \
# 3429022      19060     Amanabad      MAAA     Markazi 34.01 49.93
# 3429023      19060     Amanabad      MAAA     Markazi 34.01 49.93
# 3429024      19060     Amanabad      MAAA     Markazi 34.01 49.93
# 3429025      19060     Amanabad      MAAA     Markazi 34.01 49.93
# 3429026      19060     Amanabad      MAAA     Markazi 34.01 49.93
# ...            ...          ...       ...         ...   ...   ...
# 3429998      19060     Amanabad      MAAA     Markazi 34.01 49.93
# 3429999      19060     Amanabad      MAAA     Markazi 34.01 49.93
# 3430000      19060     Amanabad      MAAA     Markazi 34.01 49.93
# 3430001      19060     Amanabad      MAAA     Markazi 34.01 49.93
# 3430002      19060     Amanabad      MAAA     Markazi 34.01 49.93
#
#          station_elevation                date  tmax  tmin    tm  umax  umin  \
# 3429022            1728.00 2023-01-01 12:00:00  5.30 -6.70 -0.70   NaN   NaN
# 3429023            1728.00 2023-01-02 12:00:00  4.00 -7.00 -1.50   NaN   NaN
# 3429024            1728.00 2023-01-03 12:00:00  3.40 -8.40 -2.50   NaN   NaN
# 3429025            1728.00 2023-01-04 12:00:00  2.20 -7.80 -2.80   NaN   NaN
# 3429026            1728.00 2023-01-05 12:00:00  2.70 -2.30  0.20   NaN   NaN
# ...                    ...                 ...   ...   ...   ...   ...   ...
# 3429998            1728.00 2025-09-17 12:00:00 31.10 10.70 20.90   NaN   NaN
# 3429999            1728.00 2025-09-18 12:00:00 32.20 10.00 21.10   NaN   NaN
# 3430000            1728.00 2025-09-19 12:00:00 32.60 16.70 24.65   NaN   NaN
# 3430001            1728.00 2025-09-20 12:00:00 30.50 15.70 23.10   NaN   NaN
# 3430002            1728.00 2025-09-21 12:00:00 30.20  7.90 19.05   NaN   NaN
#
#          um  ffm  sshn  rrr24  FAO56  Hargreaves
# 3429022 NaN  NaN   NaN   0.00    NaN        0.95
# 3429023 NaN  NaN   NaN   0.00    NaN        0.87
# 3429024 NaN  NaN   NaN   0.80    NaN        0.85
# 3429025 NaN  NaN   NaN   0.00    NaN        0.77
# 3429026 NaN  NaN   NaN   0.80    NaN        0.66
# ...      ..  ...   ...    ...    ...         ...
# 3429998 NaN  NaN   NaN   0.00    NaN        5.19
# 3429999 NaN  NaN   NaN   0.00    NaN        5.41
# 3430000 NaN  NaN   NaN   0.00    NaN        4.98
# 3430001 NaN  NaN   NaN   0.00    NaN        4.59
# 3430002 NaN  NaN   NaN   0.00    NaN        5.02
#
# [981 rows x 19 columns]
# Reindexing station 40769
#         station_id station_name region_id region_name   lat   lon  \
# 3430003      40769         Arak      MAAA     Markazi 34.07 49.78
# 3430004      40769         Arak      MAAA     Markazi 34.07 49.78
# 3430005      40769         Arak      MAAA     Markazi 34.07 49.78
# 3430006      40769         Arak      MAAA     Markazi 34.07 49.78
# 3430007      40769         Arak      MAAA     Markazi 34.07 49.78
# ...            ...          ...       ...         ...   ...   ...
# 3455732      40769         Arak      MAAA     Markazi 34.07 49.78
# 3455733      40769         Arak      MAAA     Markazi 34.07 49.78
# 3455734      40769         Arak      MAAA     Markazi 34.07 49.78
# 3455735      40769         Arak      MAAA     Markazi 34.07 49.78
# 3455736      40769         Arak      MAAA     Markazi 34.07 49.78
#
#          station_elevation                date  tmax  tmin    tm  umax  umin  \
# 3430003            1702.80 1955-03-01 12:00:00 21.00  3.00 12.00 71.00 15.00
# 3430004            1702.80 1955-03-02 12:00:00 18.00  6.00 12.00 49.00 17.00
# 3430005            1702.80 1955-03-03 12:00:00 19.00  2.00 10.50 74.00 17.00
# 3430006            1702.80 1955-03-04 12:00:00 17.00  7.00 12.00 86.00 25.00
# 3430007            1702.80 1955-03-05 12:00:00 19.00  9.00 14.00 54.00 24.00
# ...                    ...                 ...   ...   ...   ...   ...   ...
# 3455732            1702.80 2025-09-17 12:00:00 32.40 13.80 23.10 50.00  8.00
# 3455733            1702.80 2025-09-18 12:00:00 32.50 12.80 22.60 29.00 11.00
# 3455734            1702.80 2025-09-19 12:00:00 32.60 15.30 23.90 35.00  8.00
# 3455735            1702.80 2025-09-20 12:00:00 30.10 16.00 23.00 37.00  5.00
# 3455736            1702.80 2025-09-21 12:00:00 29.90 12.10 21.00 26.00  6.00
#
#            um  ffm  sshn  rrr24  FAO56  Hargreaves
# 3430003 34.38 2.88   NaN   0.00    NaN        3.14
# 3430004 31.25 2.75   NaN   0.00    NaN        2.58
# 3430005 39.38 5.00   NaN   0.00    NaN        2.94
# 3430006 42.75 8.88   NaN   0.00    NaN        2.40
# 3430007 40.12 5.12   NaN   0.00    NaN        2.59
# ...       ...  ...   ...    ...    ...         ...
# 3455732 23.50 1.83 10.90   0.00   5.27        5.25
# 3455733 19.00 1.92 11.00   0.00   5.63        5.30
# 3455734 18.54 4.17 10.70   0.00   7.70        5.09
# 3455735 16.17 3.33 11.10   0.00   6.69        4.46
# 3455736 15.46 2.12 10.90   0.00   5.56        4.73
#
# [25734 rows x 19 columns]
# Reindexing station 40891
#         station_id station_name region_id region_name   lat   lon  \
# 3501268      40891     Mahallat      MAAA     Markazi 33.89 50.48
# 3501269      40891     Mahallat      MAAA     Markazi 33.89 50.48
# 3501270      40891     Mahallat      MAAA     Markazi 33.89 50.48
# 3501271      40891     Mahallat      MAAA     Markazi 33.89 50.48
# ...
# 3968737             879.10 2025-09-20 12:00:00 34.10 20.70 27.40 34.00 14.00
# 3968738             879.10 2025-09-21 12:00:00 33.20 15.20 24.20 48.00 18.00
#
#            um  ffm  sshn  rrr24  FAO56  Hargreaves
# 3949089   NaN 3.25   NaN   0.00    NaN         NaN
# 3949090   NaN 2.40   NaN   0.00    NaN         NaN
# 3949091   NaN 1.80   NaN   0.00    NaN         NaN
# 3949092   NaN 1.60   NaN   0.00    NaN         NaN
# 3949093   NaN 1.40   NaN   0.00    NaN         NaN
# ...       ...  ...   ...    ...    ...         ...
# 3968734 31.21 1.58 10.70   0.00   5.11        5.89
# 3968735 31.58 2.08 10.30   0.00   5.70        5.68
# 3968736 25.04 2.67 10.10   0.00   7.15        6.44
# 3968737 24.75 4.33 10.30   0.00   8.37        4.80
# 3968738 28.68 2.36 10.00   0.00   5.61        5.12
#
# [19650 rows x 19 columns]
# Reindexing station 40887
#         station_id station_name region_id region_name   lat   lon  \
# 3968739      40887  Salafchegan      QOQM         Qom 34.48 50.47
# 3968740      40887  Salafchegan      QOQM         Qom 34.48 50.47
# 3968741      40887  Salafchegan      QOQM         Qom 34.48 50.47
# 3968742      40887  Salafchegan      QOQM         Qom 34.48 50.47
# 3968743      40887  Salafchegan      QOQM         Qom 34.48 50.47
# ...            ...          ...       ...         ...   ...   ...
# 3977020      40887  Salafchegan      QOQM         Qom 34.48 50.47
# 3977021      40887  Salafchegan      QOQM         Qom 34.48 50.47
# 3977022      40887  Salafchegan      QOQM         Qom 34.48 50.47
# 3977023      40887  Salafchegan      QOQM         Qom 34.48 50.47
# 3977024      40887  Salafchegan      QOQM         Qom 34.48 50.47
#
#          station_elevation                date  tmax  tmin    tm  umax  umin  \
# 3968739            1381.40 2003-01-01 12:00:00 11.50 -3.80  6.00 68.00 24.00
# 3968740            1381.40 2003-01-02 12:00:00 11.50 -3.60  6.10 69.00 25.00
# 3968741            1381.40 2003-01-03 12:00:00 11.00 -2.80  5.40 69.00 29.00
# 3968742            1381.40 2003-01-04 12:00:00  7.50 -2.40  4.30 73.00 33.00
# 3968743            1381.40 2003-01-05 12:00:00  7.00 -2.50  4.60 83.00 49.00
# ...                    ...                 ...   ...   ...   ...   ...   ...
# 3977020            1381.40 2025-09-17 12:00:00 32.30 18.00 25.10 35.00 13.00
# 3977021            1381.40 2025-09-18 12:00:00 32.00 17.80 24.90 23.00 12.00
# 3977022            1381.40 2025-09-19 12:00:00 37.00 19.00 28.00 22.00  4.00
# 3977023            1381.40 2025-09-20 12:00:00 33.20 21.20 27.20 22.00  3.00
# 3977024            1381.40 2025-09-21 12:00:00 28.90 16.10 22.50 30.00 11.00
#
#            um   ffm  sshn  rrr24  FAO56  Hargreaves
# 3968739 36.60  4.00  9.30   0.00   1.89        1.48
# 3968740 39.40  2.00  9.30   0.00   1.44        1.49
# 3968741 41.00  2.80  9.30   0.00   1.63        1.38
# 3968742 51.40  2.40  0.00   0.00   1.26        1.12
# 3968743 62.00 13.20  4.10   0.00   1.62        1.12
# ...       ...   ...   ...    ...    ...         ...
# 3977020 20.42  3.50 10.80   0.00   7.23        4.81
# 3977021 16.88  3.42 10.00   0.00   7.38        4.74
# 3977022 12.25  5.38 10.00   0.00  10.48        5.70
# 3977023 12.14  4.38 10.50   0.00   8.88        4.54
# 3977024 15.86  3.73  9.50   0.00   6.87        4.15
#
# [8286 rows x 19 columns]
# Reindexing station 99413
#         station_id            station_name region_id region_name   lat   lon  \
# 3945093      99413  Kushk-E-Nosrat-Airport      QOQM         Qom 34.97 50.80
# 3945094      99413  Kushk-E-Nosrat-Airport      QOQM         Qom 34.97 50.80
# 3945095      99413  Kushk-E-Nosrat-Airport      QOQM         Qom 34.97 50.80
# 3945096      99413  Kushk-E-Nosrat-Airport      QOQM         Qom 34.97 50.80
# 3945097      99413  Kushk-E-Nosrat-Airport      QOQM         Qom 34.97 50.80
# ...            ...                     ...       ...         ...   ...   ...
# 3946184      99413  Kushk-E-Nosrat-Airport      QOQM         Qom 34.97 50.80
# 3946185      99413  Kushk-E-Nosrat-Airport      QOQM         Qom 34.97 50.80
# 3946186      99413  Kushk-E-Nosrat-Airport      QOQM         Qom 34.97 50.80
# 3946187      99413  Kushk-E-Nosrat-Airport      QOQM         Qom 34.97 50.80
# 3946188      99413  Kushk-E-Nosrat-Airport      QOQM         Qom 34.97 50.80
#
#          station_elevation                date  tmax  tmin    tm  umax  umin  \
# 3945093             922.00 2011-01-01 12:00:00 15.00  0.00  9.80 40.00 18.00
# 3945094             922.00 2011-01-02 12:00:00 15.20  5.40 11.00 61.00 34.00
# 3945095             922.00 2011-01-03 12:00:00 15.00  3.00 10.00 49.00 27.00
# 3945096             922.00 2011-01-04 12:00:00 12.00  2.00  7.60 61.00 28.00
# 3945097             922.00 2011-01-05 12:00:00 11.00  3.20  8.30 84.00 51.00
# ...                    ...                 ...   ...   ...   ...   ...   ...
# 3946184             922.00 2013-12-27 12:00:00 10.40 -3.00  4.10 64.00 33.00
# 3946185             922.00 2013-12-28 12:00:00  7.20 -1.40  3.40 75.00 44.00
# 3946186             922.00 2013-12-29 12:00:00  8.80 -1.60  4.20 71.00 27.00
# 3946187             922.00 2013-12-30 12:00:00  7.60 -3.40  2.70 58.00 30.00
# 3946188             922.00 2013-12-31 12:00:00  7.20 -3.20  2.90 59.00 35.00
#
#            um  ffm  sshn  rrr24  FAO56  Hargreaves
# 3945093 29.40 1.80  8.00   0.00   1.92        1.68
# 3945094 46.60 4.60  8.00   0.00   2.72        1.42
# 3945095 35.00 5.40  9.00   0.00   3.26        1.53
# 3945096 39.20 0.00  3.40   0.00   0.61        1.27
# 3945097 63.60 0.00  3.80   0.10   0.68        1.16
# ...       ...  ...   ...    ...    ...         ...
# 3946184 47.80 0.60   NaN   0.00    NaN        1.24
# 3946185 55.60 0.00   NaN   0.00    NaN        0.96
# 3946186 47.00 0.60   NaN   0.00    NaN        1.10
# 3946187 44.20 1.00   NaN   0.00    NaN        1.06
# 3946188 45.00 0.60   NaN   0.00    NaN        1.04
#
# [1096 rows x 19 columns]
# Reindexing station 99414
#         station_id    station_name region_id region_name   lat   lon  \
# 3939055      99414  Kushk-E-Nosrat      QOQM         Qom 35.09 50.90
# 3939056      99414  Kushk-E-Nosrat      QOQM         Qom 35.09 50.90
# 3939057      99414  Kushk-E-Nosrat      QOQM         Qom 35.09 50.90
# 3939058      99414  Kushk-E-Nosrat      QOQM         Qom 35.09 50.90
# 3939059      99414  Kushk-E-Nosrat      QOQM         Qom 35.09 50.90
# ...            ...             ...       ...         ...   ...   ...
# 3945088      99414  Kushk-E-Nosrat      QOQM         Qom 35.09 50.90
# 3945089      99414  Kushk-E-Nosrat      QOQM         Qom 35.09 50.90
# 3945090      99414  Kushk-E-Nosrat      QOQM         Qom 35.09 50.90
# 3945091      99414  Kushk-E-Nosrat      QOQM         Qom 35.09 50.90
# 3945092      99414  Kushk-E-Nosrat      QOQM         Qom 35.09 50.90
#
#          station_elevation                date  tmax  tmin    tm  umax  umin  \
# 3939055             948.00 2006-10-01 12:00:00 33.40 19.60 28.20 30.00 11.00
# 3939056             948.00 2006-10-02 12:00:00 34.40 20.60 30.00 24.00 10.00
# 3939057             948.00 2006-10-03 12:00:00 33.80 20.00 29.60 23.00  9.00
# 3939058             948.00 2006-10-04 12:00:00 36.40 20.00 30.30 22.00  8.00
# 3939059             948.00 2006-10-05 12:00:00 34.40 21.80 29.50 30.00  9.00
# ...                    ...                 ...   ...   ...   ...   ...   ...
# 3945088             948.00 2025-09-17 12:00:00 34.90 23.40 29.20 35.00 12.00
# 3945089             948.00 2025-09-18 12:00:00 33.80 19.00 26.40 43.00 13.00
# 3945090             948.00 2025-09-19 12:00:00 37.80 23.20 30.50 23.00  8.00
# 3945091             948.00 2025-09-20 12:00:00 33.10 25.30 29.20 22.00 10.00
# 3945092             948.00 2025-09-21 12:00:00 31.50 18.50 25.00 35.00 11.00
#
#            um  ffm  sshn  rrr24  FAO56  Hargreaves
# 3939055 16.80 2.00 10.20   0.00   5.34        4.55
# 3939056 14.20 2.40  9.00   0.00   5.82        4.69
# 3939057 14.20 2.40 10.00   0.00   5.79        4.62
# 3939058 12.40 4.60  9.70   0.00   8.78        5.07
# 3939059 17.20 4.40 10.00   0.00   8.12        4.33
# ...       ...  ...   ...    ...    ...         ...
# 3945088 18.76 2.72 11.20   0.00   7.07        4.72
# 3945089 23.12 2.70 11.20   0.00   6.51        4.98
# 3945090 13.79 4.77 10.50   0.00  10.21        5.39
# 3945091 14.59 6.94 11.20   0.00  11.67        3.80
# 3945092 20.09 2.91 10.70   0.00   6.54        4.42
#
# [6038 rows x 19 columns]
# Reindexing station 99426
#         station_id station_name region_id region_name   lat   lon  \
# 3938074      99426    Kouhsefid      QOQM         Qom 34.78 51.18
# 3938075      99426    Kouhsefid      QOQM         Qom 34.78 51.18
# 3938076      99426    Kouhsefid      QOQM         Qom 34.78 51.18
# 3938077      99426    Kouhsefid      QOQM         Qom 34.78 51.18
# 3938078      99426    Kouhsefid      QOQM         Qom 34.78 51.18
# ...            ...          ...       ...         ...   ...   ...
# 3939050      99426    Kouhsefid      QOQM         Qom 34.78 51.18
# 3939051      99426    Kouhsefid      QOQM         Qom 34.78 51.18
# 3939052      99426    Kouhsefid      QOQM         Qom 34.78 51.18
# 3939053      99426    Kouhsefid      QOQM         Qom 34.78 51.18
# 3939054      99426    Kouhsefid      QOQM         Qom 34.78 51.18
#
#          station_elevation                date  tmax  tmin    tm  umax  umin  \
# 3938074             853.00 2023-01-01 12:00:00 13.90 -3.10  5.40 76.00 35.00
# 3938075             853.00 2023-01-02 12:00:00 13.70 -3.10  5.30 72.00 32.00
# 3938076             853.00 2023-01-03 12:00:00 12.90 -4.00  4.40 73.00 30.00
# 3938077             853.00 2023-01-04 12:00:00  9.30 -5.80  1.80 71.00 35.00
# 3938078             853.00 2023-01-05 12:00:00  9.50  2.20  5.80 84.00 47.00
# ...                    ...                 ...   ...   ...   ...   ...   ...
# 3939050             853.00 2025-09-17 12:00:00 36.80 18.50 27.60 43.00 11.00
# 3939051             853.00 2025-09-18 12:00:00 37.00 20.50 28.80 49.00 11.00
# 3939052             853.00 2025-09-19 12:00:00 39.70 18.00 28.90 30.00  7.00
# 3939053             853.00 2025-09-20 12:00:00 36.00 20.30 28.10 26.00  6.00
# 3939054             853.00 2025-09-21 12:00:00 32.30 17.20 24.80 44.00 11.00
#
#            um  ffm  sshn  rrr24  FAO56  Hargreaves
# 3938074 57.50 1.71   NaN   0.00    NaN        1.51
# 3938075 53.75 1.88   NaN   0.00    NaN        1.50
# 3938076 51.75 1.67   NaN   0.00    NaN        1.45
# 3938077 52.88 1.67   NaN   0.00    NaN        1.21
# 3938078 64.12 2.92   NaN   0.00    NaN        1.02
# ...       ...  ...   ...    ...    ...         ...
# 3939050 22.08 1.90 10.30   0.00   5.92        5.76
# 3939051 26.54 3.04 10.70   0.00   7.09        5.58
# 3939052 15.50 2.38 10.30   0.00   7.09        6.37
# 3939053 15.25 5.04 10.80   0.00   9.98        5.28
# 3939054 23.48 3.13 10.50   0.00   6.52        4.76
#
# [981 rows x 19 columns]
# Reindexing station 99440
#         station_id station_name region_id region_name   lat   lon  \
# 3930151      99440        Kahak      QOQM         Qom 34.40 50.87
# 3930152      99440        Kahak      QOQM         Qom 34.40 50.87
# 3930153      99440        Kahak      QOQM         Qom 34.40 50.87
# 3930154      99440        Kahak      QOQM         Qom 34.40 50.87
# 3930155      99440        Kahak      QOQM         Qom 34.40 50.87
# ...            ...          ...       ...         ...   ...   ...
# 3938069      99440        Kahak      QOQM         Qom 34.40 50.87
# 3938070      99440        Kahak      QOQM         Qom 34.40 50.87
# 3938071      99440        Kahak      QOQM         Qom 34.40 50.87
# 3938072      99440        Kahak      QOQM         Qom 34.40 50.87
# 3938073      99440        Kahak      QOQM         Qom 34.40 50.87
#
#          station_elevation                date  tmax  tmin    tm  umax  umin  \
# 3930151            1403.10 2004-01-01 12:00:00  2.80 -3.40  0.40   NaN   NaN
# 3930152            1403.10 2004-01-02 12:00:00  1.00 -1.80  0.00   NaN   NaN
# 3930153            1403.10 2004-01-03 12:00:00  1.00 -1.00 -0.40   NaN   NaN
# 3930154            1403.10 2004-01-04 12:00:00  6.80 -2.40  3.40   NaN   NaN
# 3930155            1403.10 2004-01-05 12:00:00  9.00 -0.80  4.90   NaN   NaN
# ...                    ...                 ...   ...   ...   ...   ...   ...
# 3938069            1403.10 2025-09-17 12:00:00 31.40 16.90 24.10 41.00 18.00
# 3938070            1403.10 2025-09-18 12:00:00 30.90 16.70 23.80 33.00 18.00
# 3938071            1403.10 2025-09-19 12:00:00 35.70 17.50 26.60 28.00  8.00
# 3938072            1403.10 2025-09-20 12:00:00 32.60 19.40 26.00 27.00  5.00
# 3938073            1403.10 2025-09-21 12:00:00 27.10 14.70 20.90 29.00 19.00
#
#            um  ffm  sshn  rrr24  FAO56  Hargreaves
# 3930151   NaN 2.80   NaN   0.00    NaN        0.72
# 3930152   NaN 0.00   NaN   3.00    NaN        0.48
# 3930153   NaN 2.20   NaN   3.01    NaN        0.39
# 3930154   NaN 1.80   NaN  12.00    NaN        1.04
# 3930155   NaN 1.20   NaN   0.00    NaN        1.15
# ...       ...  ...   ...    ...    ...         ...
# 3938069 26.17 3.17 10.70   0.00   6.52        4.73
# 3938070 24.25 3.25 10.80   0.00   6.74        4.62
# 3938071 17.70 3.13 10.00   0.00   7.43        5.56
# 3938072 18.00 3.14 11.00   0.00   7.23        4.63
# 3938073 23.46 3.67  9.90   0.00   6.46        3.92
#
# [7923 rows x 19 columns]
#                         date station_id       station_name region_id  \
# 0        1951-01-01 12:00:00      18554  Zidashte Taleghan      ALKK
# 1        1951-01-02 12:00:00      18554  Zidashte Taleghan      ALKK
# 2        1951-01-03 12:00:00      18554  Zidashte Taleghan      ALKK
# 3        1951-01-04 12:00:00      18554  Zidashte Taleghan      ALKK
# 4        1951-01-05 12:00:00      18554  Zidashte Taleghan      ALKK
# ...                      ...        ...                ...       ...
# 21152070 2025-09-17 12:00:00      99440              Kahak      QOQM
# 21152071 2025-09-18 12:00:00      99440              Kahak      QOQM
# 21152072 2025-09-19 12:00:00      99440              Kahak      QOQM
# 21152073 2025-09-20 12:00:00      99440              Kahak      QOQM
# 21152074 2025-09-21 12:00:00      99440              Kahak      QOQM
#
#          region_name   lat   lon  station_elevation  tmax  tmin    tm  umax  \
# 0             Alborz 36.13 50.68            2255.00   NaN   NaN   NaN   NaN
# 1             Alborz 36.13 50.68            2255.00   NaN   NaN   NaN   NaN
# 2             Alborz 36.13 50.68            2255.00   NaN   NaN   NaN   NaN
# 3             Alborz 36.13 50.68            2255.00   NaN   NaN   NaN   NaN
# 4             Alborz 36.13 50.68            2255.00   NaN   NaN   NaN   NaN
# ...              ...   ...   ...                ...   ...   ...   ...   ...
# 21152070         Qom 34.40 50.87            1403.10 31.40 16.90 24.10 41.00
# 21152071         Qom 34.40 50.87            1403.10 30.90 16.70 23.80 33.00
# 21152072         Qom 34.40 50.87            1403.10 35.70 17.50 26.60 28.00
# 21152073         Qom 34.40 50.87            1403.10 32.60 19.40 26.00 27.00
# 21152074         Qom 34.40 50.87            1403.10 27.10 14.70 20.90 29.00
#
#           umin    um  ffm  sshn  rrr24  FAO56  Hargreaves
# 0          NaN   NaN  NaN   NaN    NaN    NaN         NaN
# 1          NaN   NaN  NaN   NaN    NaN    NaN         NaN
# 2          NaN   NaN  NaN   NaN    NaN    NaN         NaN
# 3          NaN   NaN  NaN   NaN    NaN    NaN         NaN
# 4          NaN   NaN  NaN   NaN    NaN    NaN         NaN
# ...        ...   ...  ...   ...    ...    ...         ...
# 21152070 18.00 26.17 3.17 10.70   0.00   6.52        4.73
# 21152071 18.00 24.25 3.25 10.80   0.00   6.74        4.62
# 21152072  8.00 17.70 3.13 10.00   0.00   7.43        5.56
# 21152073  5.00 18.00 3.14 11.00   0.00   7.23        4.63
# 21152074 19.00 23.46 3.67  9.90   0.00   6.46        3.92
#
# [21152075 rows x 19 columns]

# %%
import matplotlib.pyplot as plt

# Select a few station_ids to plot (change as needed) + FAO56 and Hargreaves (point and line)
stations_to_plot = result['station_id'].drop_duplicates().sample(1)

plt.figure(figsize=(12, 6))
for sid in stations_to_plot:
    station_data = result[result['station_id'] == sid].sort_values('date')
    # plt.plot(station_data['date'], station_data['FAO56'], label=f'Station {sid} - FAO56')
    plt.scatter(station_data['date'], station_data['FAO56'], color='blue', label=f'Station {sid} - FAO56')
    plt.scatter(station_data['date'], station_data['Hargreaves'], color='red', label=f'Station {sid} - Hargreaves')

plt.xlabel('Date')
plt.ylabel('ETo')
plt.title('ETo Time Series for Selected Stations')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Change Column Names

# %%
result.columns
# Out:
# Index(['date', 'station_id', 'station_name', 'region_id', 'region_name', 'lat',
#        'lon', 'station_elevation', 'tmax', 'tmin', 'tm', 'umax', 'umin', 'um',
#        'ffm', 'sshn', 'rrr24', 'FAO56', 'Hargreaves'],
#       dtype='object')

# %%
# result.rename(
#     columns={
#         'FAO-56': 'FAO56',
#         'Priestley-Taylor': 'PriestleyTaylor',
#         'Kimberly-Penman': 'KimberlyPenman',
#         'Thom-Oliver': 'ThomOliver',
#         'Blaney-Criddle': 'BlaneyCriddle',
#         'Jensen-Haise': 'JensenHaise',
#         'Mcguinness-Bordne': 'McguinnessBordne',
#         'FAO-24': 'FAO24',
#     }, 
#     inplace=True
# )

# %% [markdown]
# # Export Data

# %%
# To pickle in data folder
# with open('../../data/Khorasan_ETo_1950_2025.pkl', 'wb') as f:
with open('../../data/Iran_ETo_1950_2025.pkl', 'wb') as f:
    pickle.dump(result, f)
